# %%
#import ee
#ee.Authenticate()

# %%
import geojson
from shapely.geometry import Polygon

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

import pandas as pd
from datetime import datetime

import os
import ipywidgets as widgets

import tkinter as tk
from tkinter import filedialog as fd

import ee
import geemap
ee.Initialize()

# %%
# VARIABLES GLOBALES
RUTA_CATASTRO = ''
CATASTRO = None
PROPIEDAD = None

# %%
Map = geemap.Map(basemap="SATELLITE")

# %%
# FUNCIONES GENERALES

# open file dialog
def open_file_dialogo():
    root = tk.Tk()
    root.attributes('-topmost', True)
    root.iconify()
    file_name = fd.askopenfilename(parent=root, filetypes=[(".shp", ".shp")])
    root.destroy()
    return file_name

# quita los caracteres especiales de un texto enviado
def quitar_caracteres(text):
    text = text.replace('_', ' ')
    text = text.replace('"', '')
    text = text.replace('.', '')
    return text

# %%
vis_params_caña = {
    'color': 'red', 
    'width': 2,
    'lineType': 'solid',
    'fillColor': '00000000',
}

# %%
# FUNNCIONES DE WIDGETS

# btn_cargar_catastro
def cargar_catastro(gui):
    global CATASTRO
    file_name = open_file_dialogo()
    txt_path_catastro.value = file_name
    CATASTRO = gpd.read_file(file_name)

def cargar_propiedad(gui):
    global PROPIEDAD
    PROPIEDAD = CATASTRO[CATASTRO['unidad_01']==txt_cod_prop.value]
    # elimina la coordenada Z
    Map.add_gdf(PROPIEDAD, layer_name='capa_geopandas')
    #Map.addLayer(LOTES_RENOVACION.style(**vis_params_renov), {}, 'Lotes Renovación')
    #Map.remove_labels()
    #Map.add_labels(LOTES_CAÑA, LOTES, font_size='9pt', font_color='black', font_family='arial', font_weight='bold')

# %%
# textbox ruta de catastro
txt_path_catastro = widgets.Text(
    value=RUTA_CATASTRO,
    disabled=False,
    #layout=widgets.Layout(width='auto', height='40px')
)

# boton cargar ruta de catastro
btn_cargar_catastro = widgets.Button(
    description='Cargar Catastro',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Cargar',
)
btn_cargar_catastro.on_click(cargar_catastro)

# textbox codigo propiedad
txt_cod_prop = widgets.BoundedIntText(
    value=30,
    min=0,
    max=99999999999999999,
    step=1,
    disabled=False
)

# boton cargar propiedad
btn_cargar_propiedad = widgets.Button(
    description='Cargar Propiedad',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Cargar propiedad',
)
btn_cargar_propiedad.on_click(cargar_propiedad)

# %%
form_item_layout = widgets.Layout(
    display='flex',
    flex_flow='row',
    width='100%'
)

form_items = [
    widgets.Box([widgets.Label(value='CATASTRO:'), txt_path_catastro], layout=form_item_layout),
    widgets.Box([btn_cargar_catastro], layout=form_item_layout),
    widgets.Box([widgets.Label(value='COD PROP:'), txt_cod_prop], layout=form_item_layout),
    widgets.Box([btn_cargar_propiedad], layout=form_item_layout)
]

form = widgets.Box(form_items, layout=widgets.Layout(
    display='flex',
    flex_flow='column',
    border='solid 1px',
    align_items='stretch',
    width='100%'
))
form
# Out:
# Box(children=(Box(children=(Label(value='CATASTRO:'), Text(value='')), layout=Layout(display='flex', flex_flow…

# %%
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
# convierte las columnas unidad_01 y unidad_03 a entero
PROPIEDAD = PROPIEDAD.astype({
    'unidad_01':'int',
    'unidad_03':'int'
})

# extraer nombre de propiedad
file_name = str(propiedad.iloc[0]['unidad_01']) + '_' + propiedad.iloc[0]['unidad_02']

# se cambia el nombre de tres columnas
propiedad = propiedad.rename(columns={'id':'cod', 'variedad':'var', 'textura':'tex'})

# %%
num_columnas = len(propiedad.columns)
num_columnas
# Out:
# 15

# %%
propiedad['NOM_LOTE'] = propiedad['unidad_05']
propiedad['TEXTURA'] = propiedad['tex']
propiedad['SUPERFICIE'] = propiedad['area']
propiedad['VARIEDAD'] = propiedad['var']
propiedad['FECHA_SIEM'] = propiedad['fs']
propiedad['CORTE'] = propiedad['soca']
propiedad['ESTADO'] = ''
propiedad['RENDIMIENT'] = 0
propiedad['COD_CA'] = propiedad['unidad_03']
propiedad['COD_PROP'] = propiedad['unidad_01']
propiedad['ID'] = propiedad['cod']
propiedad['CUADRANTE'] = 0

# %%
propiedad.head(3)
# Out:
#                 cod  unidad_01      unidad_02  unidad_03
# 1902  00002200000L1        220  SANTA_BARBARA       2641  \
# 1903  00002200000L2        220  SANTA_BARBARA       2641
# 1904  00002200000L3        220  SANTA_BARBARA       2641
#
#                         unidad_04 unidad_05         var   fs tex financia
# 1902  CRONENBOLD_AGUILERA_ROBERTO        L1  RENOVACION  NaN   Y      NaN  \
# 1903  CRONENBOLD_AGUILERA_ROBERTO        L2  RENOVACION  NaN  FA      NaN
# 1904  CRONENBOLD_AGUILERA_ROBERTO        L3  RENOVACION  NaN  FA      NaN
#
#       ...  SUPERFICIE    VARIEDAD  FECHA_SIEM  CORTE ESTADO RENDIMIENT COD_CA
# 1902  ...       16.40  RENOVACION         NaN    122                 0   2641  \
# 1903  ...       11.32  RENOVACION         NaN    122                 0   2641
# 1904  ...       14.17  RENOVACION         NaN    122                 0   2641
#
#       COD_PROP             ID CUADRANTE
# 1902       220  00002200000L1         0
# 1903       220  00002200000L2         0
# 1904       220  00002200000L3         0
#
# [3 rows x 27 columns]

# %%
propiedad.columns
# Out:
# Index(['cod', 'unidad_01', 'unidad_02', 'unidad_03', 'unidad_04', 'unidad_05',
#        'var', 'fs', 'tex', 'financia', 'soca', 'cultivo', 'zona', 'area',
#        'geometry', 'NOM_LOTE', 'TEXTURA', 'SUPERFICIE', 'VARIEDAD',
#        'FECHA_SIEM', 'CORTE', 'ESTADO', 'RENDIMIENT', 'COD_CA', 'COD_PROP',
#        'ID', 'CUADRANTE'],
#       dtype='object')

# %%
propiedad = propiedad.iloc[:,num_columnas-1:]

# %%
propiedad.head(5)
# Out:
#                                                 geometry NOM_LOTE TEXTURA
# 1902   POLYGON Z ((485366.455 8085840.488 0.000, 4850...       L1       Y  \
# 1903   POLYGON Z ((484875.602 8086192.867 0.000, 4848...       L2      FA
# 1904   POLYGON Z ((485171.974 8086512.199 0.000, 4848...       L3      FA
# 11241  POLYGON Z ((484984.357 8087243.387 0.000, 4850...       L4      FY
# 11461  POLYGON Z ((485415.793 8085724.242 0.000, 4852...       L5      FY
#
#        SUPERFICIE    VARIEDAD FECHA_SIEM  CORTE ESTADO  RENDIMIENT  COD_CA
# 1902        16.40  RENOVACION        NaN    122                  0    2641  \
# 1903        11.32  RENOVACION        NaN    122                  0    2641
# 1904        14.17  RENOVACION        NaN    122                  0    2641
# 11241       11.93  RENOVACION        NaN    122                  0    2641
# 11461       36.21  RENOVACION        NaN    122                  0    2641
#
#        COD_PROP             ID  CUADRANTE
# 1902        220  00002200000L1          0
# 1903        220  00002200000L2          0
# 1904        220  00002200000L3          0
# 11241       220  00002200000L4          0
# 11461       220  00002200000L5          0

# %%
# dependiendo del año de la fecha de siembra, retorna 'HOJA', 'SOCA' o 'RENOVACION'
def establecer_estado(fecha):
    date = str(fecha)
    try:
        date = datetime.strptime(date, '%Y-%m-%d')
        year = date.year
        if year == 2022:
            return 'HOJA'
        elif year > 2000:
            return 'SOCA'
        else:
            return 'RENOVACION'
    except Exception as ex:
        return 'RENOVACION'

# %%
def establecer_formato_fecha(fecha):
    fecha = str(fecha)
    if fecha == 'None':
        return '0'
    else:
        return fecha.replace('-', '')

# %%
propiedad['ESTADO'] = propiedad['FECHA_SIEM'].apply(establecer_estado)
propiedad['FECHA_SIEM'] = propiedad['FECHA_SIEM'].apply(establecer_formato_fecha)

# %%
propiedad.head()
# Out:
#                                                 geometry NOM_LOTE TEXTURA
# 1902   POLYGON Z ((485366.455 8085840.488 0.000, 4850...       L1       Y  \
# 1903   POLYGON Z ((484875.602 8086192.867 0.000, 4848...       L2      FA
# 1904   POLYGON Z ((485171.974 8086512.199 0.000, 4848...       L3      FA
# 11241  POLYGON Z ((484984.357 8087243.387 0.000, 4850...       L4      FY
# 11461  POLYGON Z ((485415.793 8085724.242 0.000, 4852...       L5      FY
#
#        SUPERFICIE    VARIEDAD FECHA_SIEM  CORTE      ESTADO  RENDIMIENT
# 1902        16.40  RENOVACION        nan    122  RENOVACION           0  \
# 1903        11.32  RENOVACION        nan    122  RENOVACION           0
# 1904        14.17  RENOVACION        nan    122  RENOVACION           0
# 11241       11.93  RENOVACION        nan    122  RENOVACION           0
# 11461       36.21  RENOVACION        nan    122  RENOVACION           0
#
#        COD_CA  COD_PROP             ID  CUADRANTE
# 1902     2641       220  00002200000L1          0
# 1903     2641       220  00002200000L2          0
# 1904     2641       220  00002200000L3          0
# 11241    2641       220  00002200000L4          0
# 11461    2641       220  00002200000L5          0

# %%
fp_tch = r'D:\OneDrive - Ingenio Azucarero Guabira S.A\APP CAÑERO\PROPIEDADES\DATOS_PARA_GENERAR_GEOJSON\RENDIMIENTO AVANCE 071022.xlsx'

# %%
tchs = pd.read_excel(fp_tch)

# %%
tchs.head(3)
# Out:
#   COD_AVANCE  CODIGO CAÑERO   INS                 NOMBRE CAÑERO  DESSIG CREA
# 0      131_1           2224   NaN       CRUZ VARGAS WILLY WALDO     NaN  NaN  \
# 1      81_36          41555  81.0  FRANCO GUZMAN CARLA DANIELA      NaN  NaN
# 2      50_29          15501  50.0          WENDE RIOJA MAURICIO     NaN  NaN
#
#    COMPROMISO GRUPAL  COMPROMISO INDIVIDUAL  HA CANHA POR GRUPO
# 0            7067.07                   0.00                 NaN  \
# 1            7053.98                7053.98                 0.0
# 2            4525.38                4525.38                 0.0
#
#    HA CANHA INDIVIDUAL  TN ENTREGA GRUPAL  TN ENTREGADAS INDIVIDUAL
# 0                  NaN               0.00                     42.86  \
# 1                  0.0            7138.06                   7138.06
# 2                  0.0            3537.96                   3537.96
#
#    % ENTREGA GRUPAL  HA COSECHA GRUPAL  HA COSECHA INDIVIDUAL
# 0          0.000000                0.0                    0.0  \
# 1          1.011920                0.0                    0.0
# 2          0.781804                0.0                    0.0
#
#    % COSECHA GRUPAL  RENDIMIENTO 2022  RENDIMIENTO 2021
# 0               NaN               NaN               NaN  \
# 1               NaN               NaN          0.000000
# 2               NaN               NaN         39.153575
#
#    ESTIMATIVA RENDIMIENTO 2022 OBSERVACIONES
# 0                          NaN           NaN
# 1                    59.896088  SIN CATASTRO
# 2                     0.000000  SIN CATASTRO

# %%
def cargar_tch(cod_ca):
    tch = float(tchs[tchs['CODIGO CAÑERO'] == cod_ca].iloc[:,16])
    try:
        tch_float = float(tch)
        return tch_float
    except:
        return 0

# %%
#CONVERTIR LOS TIPOS DE VARIABLE
propiedad = propiedad.astype({
    'RENDIMIENT':'float',
    'COD_CA':'int',
    'COD_PROP':'int'
})

# %%
propiedad['RENDIMIENT'] = propiedad['COD_CA'].apply(cargar_tch)
propiedad.head(3)
# Out:
# C:\Users\UTEA\AppData\Local\Temp\ipykernel_18740\1276023081.py:2: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   tch = float(tchs[tchs['CODIGO CAÑERO'] == cod_ca].iloc[:,16])
#                                                geometry NOM_LOTE TEXTURA
# 1902  POLYGON Z ((485366.455 8085840.488 0.000, 4850...       L1       Y  \
# 1903  POLYGON Z ((484875.602 8086192.867 0.000, 4848...       L2      FA
# 1904  POLYGON Z ((485171.974 8086512.199 0.000, 4848...       L3      FA
#
#       SUPERFICIE    VARIEDAD FECHA_SIEM  CORTE      ESTADO  RENDIMIENT
# 1902       16.40  RENOVACION        nan    122  RENOVACION   66.142049  \
# 1903       11.32  RENOVACION        nan    122  RENOVACION   66.142049
# 1904       14.17  RENOVACION        nan    122  RENOVACION   66.142049
#
#       COD_CA  COD_PROP             ID  CUADRANTE
# 1902    2641       220  00002200000L1          0
# 1903    2641       220  00002200000L2          0
# 1904    2641       220  00002200000L3          0

# %%
fp_bloques = r'D:\OneDrive - Ingenio Azucarero Guabira S.A\APP CAÑERO\PROPIEDADES\DATOS_PARA_GENERAR_GEOJSON\BLOQUES.xlsx'

# %%
bloques = pd.read_excel(fp_bloques)

# %%
bloques.head(3)
# Out:
#     idnax               id  unidad_01       unidad_02  unidad_03
# 0  276044  00005600000L1.3        560  LA_TUJA_IAG_SA      15284  \
# 1  276045  00005600000L1.5        560  LA_TUJA_IAG_SA      15284
# 2  276046  00005600000L2.2        560  LA_TUJA_IAG_SA      15284
#
#                       unidad_04 unidad_05    variedad     fs       fc  ...
# 0  ROJAS_CORDOVA_ROGELIO_FELIPE      L1.3     UCG9020  44743  44743.0  ...  \
# 1  ROJAS_CORDOVA_ROGELIO_FELIPE      L1.5     UCG9020  44768  44768.0  ...
# 2  ROJAS_CORDOVA_ROGELIO_FELIPE      L2.2  CITTCA8522  44783  44783.0  ...
#
#    riegos_pos  agua_disp  agua_aprov agua_act  estrato  tipo_cos
# 0         NaN        NaN         NaN      NaN      NaN       NaN  \
# 1         NaN        NaN         NaN      NaN      NaN       NaN
# 2         NaN        NaN         NaN      NaN      NaN       NaN
#
#    resiembra_pct  activo  fk_estacion  inicio_curva
# 0            NaN    True          NaN           NaN
# 1            NaN    True          NaN           NaN
# 2            NaN    True          NaN           NaN
#
# [3 rows x 44 columns]

# %%
def cargar_bloque(cod_prop):
    bloque = bloques[bloques['unidad_01']==cod_prop].head(1).loc[:,'cuadrante']
    try:
        bloque_int = int(bloque)
        return bloque_int
    except:
        return 0

# %%
propiedad['CUADRANTE']=propiedad['COD_PROP'].apply(cargar_bloque)
propiedad.head(3)
# Out:
#                                                geometry NOM_LOTE TEXTURA
# 1902  POLYGON Z ((485366.455 8085840.488 0.000, 4850...       L1       Y  \
# 1903  POLYGON Z ((484875.602 8086192.867 0.000, 4848...       L2      FA
# 1904  POLYGON Z ((485171.974 8086512.199 0.000, 4848...       L3      FA
#
#       SUPERFICIE    VARIEDAD FECHA_SIEM  CORTE      ESTADO  RENDIMIENT
# 1902       16.40  RENOVACION        nan    122  RENOVACION   66.142049  \
# 1903       11.32  RENOVACION        nan    122  RENOVACION   66.142049
# 1904       14.17  RENOVACION        nan    122  RENOVACION   66.142049
#
#       COD_CA  COD_PROP             ID  CUADRANTE
# 1902    2641       220  00002200000L1          0
# 1903    2641       220  00002200000L2          0
# 1904    2641       220  00002200000L3          0

# %%
propiedad['ID'] = propiedad.apply(lambda x : '0000' + str(x['COD_PROP']) + '0000' + x['NOM_LOTE'], axis=1)

# %%
propiedad.head(3)
# Out:
#                                                geometry NOM_LOTE TEXTURA
# 1902  POLYGON Z ((485366.455 8085840.488 0.000, 4850...       L1       Y  \
# 1903  POLYGON Z ((484875.602 8086192.867 0.000, 4848...       L2      FA
# 1904  POLYGON Z ((485171.974 8086512.199 0.000, 4848...       L3      FA
#
#       SUPERFICIE    VARIEDAD FECHA_SIEM  CORTE      ESTADO  RENDIMIENT
# 1902       16.40  RENOVACION        nan    122  RENOVACION   66.142049  \
# 1903       11.32  RENOVACION        nan    122  RENOVACION   66.142049
# 1904       14.17  RENOVACION        nan    122  RENOVACION   66.142049
#
#       COD_CA  COD_PROP             ID  CUADRANTE
# 1902    2641       220  00002200000L1          0
# 1903    2641       220  00002200000L2          0
# 1904    2641       220  00002200000L3          0

# %%
propiedad.plot()
plt.show()

# %%
#quitar_caracteres
propiedad['VARIEDAD'] = propiedad['VARIEDAD'].apply(quitar_caracteres)

# %%
propiedad
# Out:
#                                                 geometry NOM_LOTE TEXTURA
# 1902   POLYGON Z ((485366.455 8085840.488 0.000, 4850...       L1       Y  \
# 1903   POLYGON Z ((484875.602 8086192.867 0.000, 4848...       L2      FA
# 1904   POLYGON Z ((485171.974 8086512.199 0.000, 4848...       L3      FA
# 11241  POLYGON Z ((484984.357 8087243.387 0.000, 4850...       L4      FY
# 11461  POLYGON Z ((485415.793 8085724.242 0.000, 4852...       L5      FY
#
#        SUPERFICIE    VARIEDAD FECHA_SIEM  CORTE      ESTADO  RENDIMIENT
# 1902        16.40  RENOVACION        nan    122  RENOVACION   66.142049  \
# 1903        11.32  RENOVACION        nan    122  RENOVACION   66.142049
# 1904        14.17  RENOVACION        nan    122  RENOVACION   66.142049
# 11241       11.93  RENOVACION        nan    122  RENOVACION   66.142049
# 11461       36.21  RENOVACION        nan    122  RENOVACION   66.142049
#
#        COD_CA  COD_PROP             ID  CUADRANTE
# 1902     2641       220  00002200000L1          0
# 1903     2641       220  00002200000L2          0
# 1904     2641       220  00002200000L3          0
# 11241    2641       220  00002200000L4          0
# 11461    2641       220  00002200000L5          0

# %%
propiedad.head()
# Out:
#                                                 geometry NOM_LOTE TEXTURA
# 1902   POLYGON Z ((485366.455 8085840.488 0.000, 4850...       L1       Y  \
# 1903   POLYGON Z ((484875.602 8086192.867 0.000, 4848...       L2      FA
# 1904   POLYGON Z ((485171.974 8086512.199 0.000, 4848...       L3      FA
# 11241  POLYGON Z ((484984.357 8087243.387 0.000, 4850...       L4      FY
# 11461  POLYGON Z ((485415.793 8085724.242 0.000, 4852...       L5      FY
#
#        SUPERFICIE    VARIEDAD FECHA_SIEM  CORTE      ESTADO  RENDIMIENT
# 1902        16.40  RENOVACION        nan    122  RENOVACION   66.142049  \
# 1903        11.32  RENOVACION        nan    122  RENOVACION   66.142049
# 1904        14.17  RENOVACION        nan    122  RENOVACION   66.142049
# 11241       11.93  RENOVACION        nan    122  RENOVACION   66.142049
# 11461       36.21  RENOVACION        nan    122  RENOVACION   66.142049
#
#        COD_CA  COD_PROP             ID  CUADRANTE
# 1902     2641       220  00002200000L1          0
# 1903     2641       220  00002200000L2          0
# 1904     2641       220  00002200000L3          0
# 11241    2641       220  00002200000L4          0
# 11461    2641       220  00002200000L5          0

# %%
propiedad.crs
# Out:
# <Projected CRS: EPSG:32720>
# Name: WGS 84 / UTM zone 20S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 66°W and 60°W, southern hemisphere between 80°S and equator, onshore and offshore. Argentina. Bolivia. Brazil. Falkland Islands (Malvinas). Paraguay.
# - bounds: (-66.0, -80.0, -60.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 20S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
propiedad = propiedad.to_crs(epsg=4326)

# %%
propiedad.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
propiedad['SUPERFICIE'].sum()
# Out:
# 90.03

# %%
file_name + '.geojson'
# Out:
# '220_SANTA_BARBARA.geojson'

# %%
#file_name='d'

# %%
os.chdir(r"D:\OneDrive - Ingenio Azucarero Guabira S.A\APP CAÑERO\PROPIEDADES\DATOS_PARA_GENERAR_GEOJSON\PROPIEDADES_OFFICIALES")

# %%
out_dir = os.path.normpath((os.getcwd() + '/' + file_name + '.geojson' ))

# %%
out_dir
# Out:
# 'D:\\OneDrive - Ingenio Azucarero Guabira S.A\\APP CAÑERO\\PROPIEDADES\\DATOS_PARA_GENERAR_GEOJSON\\PROPIEDADES_OFFICIALES\\220_SANTA_BARBARA.geojson'

# %%
propiedad.to_file(out_dir, driver='GeoJSON')
