# %%
import os
import pandas as pd
from amigocloud import AmigoCloud

# %%
files = os.listdir(r'C:\Users\UTEA\OneDrive - Ingenio Azucarero Guabira S.A (2)\UTEA_2022\EVALUACION DE COSECHADORAS\informes\WORD - Copy')
files
# Out:
# ['11171_EC_18-08-2022_QUIROZ SARAVIA TEODOCIA.docx',
#  '11645_EC_29-08-2022_ROJAS MEDRANO JUAN.docx',
#  '11852_EC_11-07-2022_ROCA GIL VICENTE.docx',
#  '12478_EC_18-07-2022_SERRATE COLAMARINO HUGO.docx',
#  '12725_EC_01-09-2022_SEJAS CLAURE SINFOROSA.docx',
#  '13062_EC_04-08-2022_SOTO ARCE BACILIO.docx',
#  '14760_EC_15-07-2022_VARGAS PINTO RENE.docx',
#  '14769_EC_18-08-2022_VARGAS URIONA MARIO.docx',
#  '1540_EC_29-08-2022_CALVI PADILLA MARIO.docx',
#  '1580_EC_11-08-2022_CALLE DELGADO IVER.docx',
#  '1648_EC_30-08-2022_CALVI PADILLA SERGIO.docx',
#  '1672_EC_07-07-2022_CAMPBELL BALCAZAR ALAN.docx',
#  '1741_EC_02-09-2022_CARO ALTAMIRANO ROSARIO.docx',
#  '17691_EC_26-07-2022_GUZMAN MONTANO PEDRO WILMER.docx',
#  '18027_EC_23-07-2022_AGUILERA TARRADELLES GUILLERMO.docx',
#  '18027_EC_25-08-2022_AGUILERA TARRADELLES GUILLERMO.docx',
#  '180_EC_15-08-2022_AMURRIO ALBARRACIN ELISEO.docx',
#  '18191_EC_01-08-2022_BALCAZAR SOLETO MARIO.docx',
# ...

# %%
# ELIMINA LA EXTENCION DE LOS NOMBRES DE LOS ARCHIVOS
f = list(map(lambda x : x[:-5], files))
f
# Out:
# ['11171_EC_18-08-2022_QUIROZ SARAVIA TEODOCIA',
#  '11645_EC_29-08-2022_ROJAS MEDRANO JUAN',
#  '11852_EC_11-07-2022_ROCA GIL VICENTE',
#  '12478_EC_18-07-2022_SERRATE COLAMARINO HUGO',
#  '12725_EC_01-09-2022_SEJAS CLAURE SINFOROSA',
#  '13062_EC_04-08-2022_SOTO ARCE BACILIO',
#  '14760_EC_15-07-2022_VARGAS PINTO RENE',
#  '14769_EC_18-08-2022_VARGAS URIONA MARIO',
#  '1540_EC_29-08-2022_CALVI PADILLA MARIO',
#  '1580_EC_11-08-2022_CALLE DELGADO IVER',
#  '1648_EC_30-08-2022_CALVI PADILLA SERGIO',
#  '1672_EC_07-07-2022_CAMPBELL BALCAZAR ALAN',
#  '1741_EC_02-09-2022_CARO ALTAMIRANO ROSARIO',
#  '17691_EC_26-07-2022_GUZMAN MONTANO PEDRO WILMER',
#  '18027_EC_23-07-2022_AGUILERA TARRADELLES GUILLERMO',
#  '18027_EC_25-08-2022_AGUILERA TARRADELLES GUILLERMO',
#  '180_EC_15-08-2022_AMURRIO ALBARRACIN ELISEO',
#  '18191_EC_01-08-2022_BALCAZAR SOLETO MARIO',
#  '18356_EC_11-07-2022_CATALA HUBBAUER JORGE ALBERTO',
#  '18358_EC_06-07-2022_ROJAS AMELUNGE CARLOS',
# ...

# %%
# CANTIDAD DE ARCHIVOSa
len(files)
# Out:
# 77

# %%
pdfs = pd.DataFrame({'nom':f})
pdfs
# Out:
#                                                  nom
# 0        11171_EC_18-08-2022_QUIROZ SARAVIA TEODOCIA
# 1             11645_EC_29-08-2022_ROJAS MEDRANO JUAN
# 2               11852_EC_11-07-2022_ROCA GIL VICENTE
# 3        12478_EC_18-07-2022_SERRATE COLAMARINO HUGO
# 4         12725_EC_01-09-2022_SEJAS CLAURE SINFOROSA
# ..                                               ...
# 72    86_EC_02-09-2022_AGUILERA TARADELLES JOSE LUIS
# 73    86_EC_21-07-2022_AGUILERA TARADELLES JOSE LUIS
# 74  8814_EC_18-07-2022_MURIALDO MENDEZ WALTER DANIEL
# 75         9278_EC_30-08-2022_NUNEZ MARTINEZ BRAULIO
# 76   9677_EC_14-07-2022_OVANDO JIMENEZ JAIRO ESTEVAN
#
# [77 rows x 1 columns]

# %%
# CONECCION A AMIGOCLOG
acceso = open('../utea_scripts/api_key/api.key','r')
api_token = acceso.readlines()[0]
acceso.close()

amigocloud = AmigoCloud(token=api_token)
amigocloud

# %%
query = {'query': 'select cast(id as varchar), split_part(canhero, \' / \', 1)|| \'_EC_\' || to_char(fecha_de_registro, \'DD-MM-YYYY\') || \'_\' || split_part(canhero, \' / \', 2) nom from dataset_296354'}
project = 'https://app.amigocloud.com/api/v1/projects/32082/sql'
cursor = amigocloud.get_cursor(project, query)
#data = select['data'][0]

# %%
lt = []
for registro in cursor:
    lt.append(registro)

# %%
df = pd.DataFrame(lt)
df
# Out:
#      id                                                nom
# 0    94             446_EC_09-09-2022_AGUILERA ANEZ JHONNY
# 1    95          1672_EC_09-09-2022_CAMPBELL BALCAZAR ALAN
# 2     4          18358_EC_18-07-2022_ROJAS AMELUNGE CARLOS
# 3    96          515_EC_10-09-2022_AGUILERA OLGA RIVERO DE
# 4    84         5307_EC_06-09-2022_HUANCA MENCHAQUE VICTOR
# ..   ..                                                ...
# 100  72    3334_EC_31-08-2022_ENRIQUEZ PAICHUCAMA ERWIN A.
# 101  10  4844_EC_19-07-2022_TARRADELLES MARTINEZ DIETER...
# 102  53        180_EC_15-08-2022_AMURRIO ALBARRACIN ELISEO
# 103  21   4839_EC_14-07-2022_GUTIERREZ TARRADELLES ALFREDO
# 104  46  3474_EC_05-08-2022_EGUEZ FOIANINI GLOVERT ESTEBAN
#
# [105 rows x 2 columns]

# %%
res = pd.merge(pdfs, df, how = 'left', on = ['nom','nom'])

# %%
print(len(res))
res
# Out:
# 77
#                                                  nom  id
# 0        11171_EC_18-08-2022_QUIROZ SARAVIA TEODOCIA  60
# 1             11645_EC_29-08-2022_ROJAS MEDRANO JUAN  66
# 2               11852_EC_11-07-2022_ROCA GIL VICENTE  24
# 3        12478_EC_18-07-2022_SERRATE COLAMARINO HUGO   9
# 4         12725_EC_01-09-2022_SEJAS CLAURE SINFOROSA  74
# ..                                               ...  ..
# 72    86_EC_02-09-2022_AGUILERA TARADELLES JOSE LUIS  75
# 73    86_EC_21-07-2022_AGUILERA TARADELLES JOSE LUIS   8
# 74  8814_EC_18-07-2022_MURIALDO MENDEZ WALTER DANIEL   1
# 75         9278_EC_30-08-2022_NUNEZ MARTINEZ BRAULIO  69
# 76   9677_EC_14-07-2022_OVANDO JIMENEZ JAIRO ESTEVAN  23
#
# [77 rows x 2 columns]

# %%
def new_name(row):
    data = row.split('_')
    return data[0] + '_EVC_' + data[2] + '_' + data[3] + '_' + data[4]

# %%
res['name_file'] = res.apply(lambda row: row.nom + '_' + str(row.id), axis=1)
res['name_file'] = res['name_file'].map(new_name)
res
# Out:
#                                                  nom  id  \
# 0        11171_EC_18-08-2022_QUIROZ SARAVIA TEODOCIA  60
# 1             11645_EC_29-08-2022_ROJAS MEDRANO JUAN  66
# 2               11852_EC_11-07-2022_ROCA GIL VICENTE  24
# 3        12478_EC_18-07-2022_SERRATE COLAMARINO HUGO   9
# 4         12725_EC_01-09-2022_SEJAS CLAURE SINFOROSA  74
# ..                                               ...  ..
# 72    86_EC_02-09-2022_AGUILERA TARADELLES JOSE LUIS  75
# 73    86_EC_21-07-2022_AGUILERA TARADELLES JOSE LUIS   8
# 74  8814_EC_18-07-2022_MURIALDO MENDEZ WALTER DANIEL   1
# 75         9278_EC_30-08-2022_NUNEZ MARTINEZ BRAULIO  69
# 76   9677_EC_14-07-2022_OVANDO JIMENEZ JAIRO ESTEVAN  23
#
#                                             name_file
# 0     11171_EVC_18-08-2022_QUIROZ SARAVIA TEODOCIA_60
# 1          11645_EVC_29-08-2022_ROJAS MEDRANO JUAN_66
# 2            11852_EVC_11-07-2022_ROCA GIL VICENTE_24
# 3      12478_EVC_18-07-2022_SERRATE COLAMARINO HUGO_9
# ...

# %%
for i in res.index:
    nom_1 = r'C:\Users\UTEA\OneDrive - Ingenio Azucarero Guabira S.A (2)\UTEA_2022\EVALUACION DE COSECHADORAS\informes\WORD - Copy\\' + res['nom'][i] + '.docx'
    nom_2 = r'C:\Users\UTEA\OneDrive - Ingenio Azucarero Guabira S.A (2)\UTEA_2022\EVALUACION DE COSECHADORAS\informes\WORD - Copy\\' + res['name_file'][i] + '.docx'
    os.rename(nom_1, nom_2)
