# %%
import requests

# %%
def enviar():
    url = "http://localhost:8080/message/sendText/UTEA CHAT"

    payload = {
        "number": "59175599909",
        "text": "hola!!!!",
    }
    headers = {
        "apikey": "A279516BD613-4387-93E4-75603E42BED5",
        "Content-Type": "application/json"
    }

    response = requests.request("POST", url, json=payload, headers=headers)

    print(response.text)

# %%
enviar()
# Out:
# {"key":{"remoteJid":"59175599909@s.whatsapp.net","fromMe":true,"id":"3EB0D1EF751695D4AEEF995C90021B03233EB14E"},"pushName":"","status":"PENDING","message":{"conversation":"hola!!!!"},"contextInfo":null,"messageType":"conversation","messageTimestamp":1732566096,"instanceId":"895c3077-a178-410c-8920-9550f6d9e588","source":"unknown"}

# %%
while True:
    enviar()
# Out:
# {"key":{"remoteJid":"59175599909@s.whatsapp.net","fromMe":true,"id":"3EB0809A5262186E82C91039FB1519339CE4AF91"},"pushName":"","status":"PENDING","message":{"conversation":"hola!!!!"},"contextInfo":null,"messageType":"conversation","messageTimestamp":1732566270,"instanceId":"895c3077-a178-410c-8920-9550f6d9e588","source":"unknown"}
# {"key":{"remoteJid":"59175599909@s.whatsapp.net","fromMe":true,"id":"3EB08F5A42F73B3F313DF86990AD6441DFAB9562"},"pushName":"","status":"PENDING","message":{"conversation":"hola!!!!"},"contextInfo":null,"messageType":"conversation","messageTimestamp":1732566270,"instanceId":"895c3077-a178-410c-8920-9550f6d9e588","source":"unknown"}
# ...
