# %% [markdown]
# 'corporate_id': 57
#
# 'company': 137
#
# 'area': 164

# %%
import json
import requests
import pandas as pd

# %%
payload = json.dumps(
    {
        "password": "A123456*",
        "email": "bsocompi@cittca.com.bo",
    }
)
headers = {
    'Content-Type': 'application/json'
}
response = requests.request(
    method="POST", 
    url="https://beta-api.naxsolutions.com/api/v1/token/pair", 
    headers=headers, 
    data=payload
)
token = response.json()['access']
token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....dLYBBDW46c33tzBXPKpO0RkrLGUVP27y6Nu4mZrCcwU'

# %%
def get_samplings(token: str, campaign_id: int, board_id: int = None,
                  sort: str = "created_at", direction: str = "ASC",
                  limit: int = 100, offset: int = 0, extra_filters: dict = None):
    
    url = "https://beta-api.naxsolutions.com/api/v1/smart_samplings/samplings"
    headers = {
        "Authorization": f"Bearer {token}"
    }

    params = {
        "campaign_id": campaign_id,
        "sort": sort,
        "direction": direction,
        "limit": limit,
        "offset": offset
    }

    if board_id:
        params["board_id"] = board_id
    if extra_filters:
        params.update(extra_filters)

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        return response.json().get("items", [])
    else:
        print(f"Error {response.status_code}: {response.text}")
        return []

# %%
campaign_id = 1111
board_id = 46
samplings = get_samplings(token, campaign_id, board_id)

# %%
df_samplings = pd.DataFrame(samplings)
df_samplings = df_samplings[df_samplings['status'] != 'finished']
df_samplings['marker_count'].sum()
# Out:
# 115

# %%
df_samplings
# Out:
#       id                              identifier sampling_date   status  \
# 3    988                    SAUSALITO-CITTCA8522    2025-04-18  pending
# 4    989                       SAUSALITO-UCG9020    2025-04-18  pending
# 5    990                  LOS ARROYOS-CITTCA8522    2025-04-18  pending
# 6    991                     LOS ARROYOS-UCG9020    2025-04-18  pending
# 7    992                         LOS ARROYOS-RB2    2025-04-18  pending
# 8    993                SAN MARIANITO-CITTCA8522    2025-04-18  pending
# 9    994                   SAN MARIANITO-UCG9020    2025-04-18  pending
# 10   995                    LA CONQUISTA-UCG9020    2025-04-18  pending
# 11   996                SSANTA MARTHA-CITTCA0563    2025-04-18  pending
# 12   997                     SANTA MARTHA-NA5626    2025-04-18  pending
# 13   998                    SANTA MARTHA-RBB7726    2025-04-18  pending
# 14   999                   SANTA MARTHA-SP835073    2025-04-18  pending
# 15  1000                    SANTA MARTHA-UCG9020    2025-04-18  pending
# 16  1001                       SANTA ANA-UCG9020    2025-04-18  pending
# 17  1002                         NAVIDAD-UCG9020    2025-04-18  pending
# 18  1003                      NAVIDAD-CITTCA0563    2025-04-18  pending
# 19  1004                     CAMPO DULCE-UCG9020    2025-04-18  pending
# 20  1005                     CAMPO DULCE-RBB7726    2025-04-18  pending
# 21  1006                         CAMPO DULCE-RB2    2025-04-18  pending
# 22  1007                  CAMPO DULCE-CITTCA0563    2025-04-18  pending
# 23  1008                  AGROPECUARIA FLAMBOYAN    2025-04-18  pending
# 24  1009                   TRES HERMANOS-UCG9020    2025-04-18  pending
# 25  1010                  DON QUIJOTE-CITTCA0563    2025-04-18  pending
# 26  1011                  DON QUIJOTE-CITTCA8522    2025-04-18  pending
# 27  1012                     DON QUIJOTE-UCG9020    2025-04-18  pending
# 28  1013                    LOS ANDES-CITTCA0563    2025-04-18  pending
# 29  1014                    LOS ANDES-CITTCA8522    2025-04-18  pending
# 30  1015                      LOS ANDES-SP835073    2025-04-18  pending
# 31  1016                       LOS ANDES-UCG9020    2025-04-18  pending
# 32  1017   LA VICTORIA--GONZALES LUIS-CITTCA8522    2025-04-18  pending
# 33  1018                       LAS MARAS-UCG9020    2025-04-18  pending
# 34  1019                      LA FORTUNA-UCG9020    2025-04-18  pending
# 35  1020                   SANTA ROSITA--UCG9020    2025-04-18  pending
# 36  1021                    LA ASUNTA-CITTCA8522    2025-04-18  pending
# 37  1022                       LA ASUNTA-UCG9020    2025-04-18  pending
# 38  1023                     SAN ANTONIO-UCG9020    2025-04-18  pending
# 39  1024  VILLA LITTE ZONA EL CIDRAL\tCITTCA8522    2025-04-18  pending
# 40  1025         VILLA LITTE ZONA EL CIDRAL\tRB2    2025-04-18  pending
# 41  1026     VILLA LITTE ZONA EL CIDRAL\tUCG9020    2025-04-18  pending
# 42  1027            NARANJAL 5 ESTRELLAS-UCG9020    2025-04-18  pending
# 43  1028                      GUAYABOCHI-UCG9020    2025-04-18  pending
# 44  1029               SANTA BARBARA\tCITTCA0563    2025-04-18  pending
# 45  1030               SANTA BARBARA\tCITTCA8522    2025-04-18  pending
# 46  1031                       SANTA BARBARA-NA1    2025-04-18  pending
# 47  1032                SANTA BARBARA - SP835073    2025-04-18  pending
#
#     marker_count  marker_completed_count  result_count
# 3              4                       0             0
# 4              2                       0             0
# 5              3                       0             0
# 6              3                       0             0
# 7              1                       0             0
# 8              4                       0             0
# 9              2                       0             0
# 10             3                       0             0
# 11             2                       0             0
# 12             1                       0             0
# 13             1                       0             0
# 14             1                       0             0
# 15             1                       0             0
# 16             2                       0             0
# 17             2                       0             0
# 18             1                       0             0
# 19             7                       0             0
# 20             2                       0             0
# 21             2                       0             0
# 22             2                       0             0
# 23             2                       0             0
# 24             3                       0             0
# 25             1                       0             0
# 26             1                       0             0
# 27             3                       0             0
# 28             1                       0             0
# 29             1                       0             0
# 30             1                       0             0
# 31             9                       0             0
# 32             2                       0             0
# 33             4                       0             0
# 34            12                       0             0
# 35             2                       0             0
# 36             3                       0             0
# 37             2                       0             0
# 38             4                       0             0
# 39             1                       0             0
# 40             1                       0             0
# 41             2                       0             0
# 42             1                       0             0
# 43             1                       0             0
# 44             1                       0             0
# 45             4                       0             0
# 46             2                       0             0
# 47             5                       0             0

# %%
def get_sampling_by_id(token: str, sampling_id: int):
    url = f"https://beta-api.naxsolutions.com/api/v1/smart_samplings/samplings/{sampling_id}"
    headers = {
        "Authorization": f"Bearer {token}"
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# %%
def parse_sampling_markers(sampling_response):
    sampling_id = sampling_response["id"]
    markers = sampling_response.get("markers", [])

    # Crear una lista de diccionarios con los campos que querés
    rows = []
    for m in markers:
        row = {
            "sampling_id": sampling_id,
            "marker_id": m.get("id"),
            "marker_name": m.get("name"),
            "value": m.get("value"),
            "lot_id": m.get("lot_id"),
            "latitude": m.get("latitude"),
            "longitude": m.get("longitude"),
            "created_at": m.get("created_at"),
            "updated_at": m.get("updated_at"),
        }
        rows.append(row)

    # Convertir en DataFrame
    return pd.DataFrame(rows)

# %%
df_res = None
for i, row in df_samplings.iterrows():
    print(row['id'])
    sampling_details = get_sampling_by_id(token, row['id'])
    df_markers = parse_sampling_markers(sampling_details)
    df_res = pd.concat([df_res, df_markers], axis=0, ignore_index=True)
# Out:
# 988
# 989
# 990
# 991
# 992
# 993
# 994
# 995
# 996
# 997
# 998
# 999
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032

# %%
df_res
# Out:
#      sampling_id  marker_id                                 marker_name  \
# 0            988     210178     1_SAUSALITO-CITTCA8522_00001140000L5.14
# 1            988     210179     2_SAUSALITO-CITTCA8522_00001140000L5.12
# 2            988     210180     3_SAUSALITO-CITTCA8522_00001140000L5.12
# 3            988     210181      4_SAUSALITO-CITTCA8522_00001140000L5.9
# 4            989     210182           1_SAUSALITO-UCG9020_00001140000L3
# ..           ...        ...                                         ...
# 110         1032     210288     1_SANTA BARBARA - SP835073_0000190000L8
# 111         1032     210289     2_SANTA BARBARA - SP835073_0000190000L8
# 112         1032     210290  3_SANTA BARBARA - SP835073_0000190000L28.1
# 113         1032     210291  4_SANTA BARBARA - SP835073_0000190000L27.2
# 114         1032     210292  5_SANTA BARBARA - SP835073_0000190000L28.1
#
#         value   lot_id   latitude  longitude                created_at  \
# 0    0.678398  1849950 -17.223590 -63.367489  2025-04-12T20:55:11.875Z
# 1    0.836963  1850236 -17.221736 -63.374198  2025-04-12T20:55:11.875Z
# 2    0.922213  1850236 -17.220251 -63.373123  2025-04-12T20:55:11.875Z
# 3    0.968073  1850110 -17.218495 -63.367343  2025-04-12T20:55:11.875Z
# 4    0.723312  1845627 -17.228845 -63.369960  2025-04-12T21:01:50.313Z
# ..        ...      ...        ...        ...                       ...
# 110  0.533537  1842662 -17.243059 -63.140725  2025-04-13T19:47:13.390Z
# 111  0.633514  1842662 -17.242157 -63.137714  2025-04-13T19:47:13.390Z
# 112  0.713193  1847649 -17.273853 -63.165368  2025-04-13T19:47:13.390Z
# 113  0.793682  1842665 -17.272958 -63.167280  2025-04-13T19:47:13.390Z
# 114  0.901610  1847649 -17.276120 -63.168694  2025-04-13T19:47:13.390Z
#
#                    updated_at
# 0    2025-04-12T20:55:11.875Z
# 1    2025-04-12T20:55:11.875Z
# 2    2025-04-12T20:55:11.875Z
# 3    2025-04-12T20:55:11.875Z
# 4    2025-04-12T21:01:50.313Z
# ..                        ...
# 110  2025-04-13T19:47:13.390Z
# 111  2025-04-13T19:47:13.390Z
# 112  2025-04-13T19:47:13.390Z
# 113  2025-04-13T19:47:13.390Z
# 114  2025-04-13T19:47:13.390Z
#
# [115 rows x 9 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
# Crear geometría de puntos desde lat/lon
geometry = [Point(xy) for xy in zip(df_res["longitude"], df_res["latitude"])]

# Crear GeoDataFrame con sistema de coordenadas WGS84
gdf = gpd.GeoDataFrame(df_res, geometry=geometry, crs="EPSG:4326")

# %%
gdf_utm = gdf.to_crs(epsg=32720)

# %%
output_path = "muestreos.shp"
gdf_utm.to_file(output_path, driver='ESRI Shapefile')
# Out:
# C:\Users\bismarksr\AppData\Local\Temp\ipykernel_16352\992117271.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_utm.to_file(output_path, driver='ESRI Shapefile')
