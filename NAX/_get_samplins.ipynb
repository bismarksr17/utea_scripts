# %%
import json
import requests
import pandas as pd

# %%
corporate_id = 57
company = 137
area = 164

campaign_id = 1111
board_id = 46

# %%
payload = json.dumps(
    {
        "password": "A123456*",
        "email": "bsocompi@cittca.com.bo",
    }
)
headers = {
    'Content-Type': 'application/json'
}
response = requests.request(
    method="POST", 
    url="https://beta-api.naxsolutions.com/api/v1/token/pair", 
    headers=headers, 
    data=payload
)
token = response.json()['access']
token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....6iBkAK8bkh-jeEuKRWhkX940p-pqM6QpBlFmD8kfOS4'

# %%
def crear_usuario_nax(token: str, email: str, password: str, first_name: str,
                       last_name: str, phone: str, company_id: int,
                       apps: list = None, grouping_unit_01_values: list = None,
                       role: str = "basic", language: str = "es-ES"):
    """
    Crea un nuevo usuario en NAX con acceso a ciertas apps
    y limita el acceso a lots específicos según grouping_unit_01.
    """
    url = "https://beta-api.naxsolutions.com/api/v1/users"
    headers = {
        "Authorization": f"Bearer {token}",
        "Content-Type": "application/json"
    }

    # Construir el campo limits
    limits = {
        "companies": [company_id]
    }

    if apps:
        limits["apps"] = apps

    if grouping_unit_01_values:
        limits["lots"] = [
            {
                "company_id": company_id,
                "fields": [
                    {
                        "name": "grouping_unit_01",
                        "values": grouping_unit_01_values
                    }
                ]
            }
        ]

    payload = {
        "email": email,
        "password": password,
        "first_name": first_name,
        "last_name": last_name,
        "phone": phone,
        "role": role,
        "language": language,
        "limits": limits
    }

    response = requests.post(url, headers=headers, data=json.dumps(payload))

    if response.status_code == 200:
        print("✅ Usuario creado exitosamente.")
        return response.json()
    else:
        print(f"❌ Error {response.status_code}: {response.text}")
        return None

# %%
crear_usuario_nax(
    token=token,
    email="usuariotest01@gmail.com",
    password="123456*123",
    first_name="Nombre",
    last_name="Apellido",
    phone="77663540",
    company_id=137,
    apps=["INSPECTIONS", "SMART_MODELS", "VARIABLE_MAPS"],
    grouping_unit_01_values=["47", "30"]  # 👈 Aquí limitás los lots
)
# Out:
# ✅ Usuario creado exitosamente.
# {'id': 5500,
#  'username': 'usuariotest01@gmail.com',
#  'email': 'usuariotest01@gmail.com',
#  'first_name': 'Nombre',
#  'last_name': 'Apellido',
#  'app_config': {'map': {'show_ids': False,
#    'recent_products': [],
#    'favorite_products': [],
#    'default_thumbnail_map_show': True},
#   'theme': 'light',
#   'language': 'es-ES',
#   'easy_mode': False,
#   'smart_models': {'selected_area': None, 'selected_campaign': None},
#   'offline': {'area_id': 0,
#    'download_histograms': False,
#    'histograms_lots_selected': [],
#    'frequency': 'last_1_images',
#    'selected_models': [],
#    'last_download_time': None,
#    'cloud_coverage_threshold': 25},
#   'show_changelog': True,
#   'inspections': {'selected_area': None,
#    'selected_board': None,
#    'selected_campaign': None}},
#  'is_active': True,
#  'is_superuser': False,
#  'corporate_id': 57,
#  'corporate_name': 'Guabira',
#  'role': 'basic',
#  'limits': {'companies': [137],
#   'apps': ['INSPECTIONS', 'SMART_MODELS', 'VARIABLE_MAPS'],
#   'plots': [487943,
#    483336,
#    483849,
#    484877,
#    789010,
#    790035,
#    486935,
#    483867,
#    483361,
#    485923,
#    485412,
#    478765,
#    487981,
#    787503,
#    487985,
#    487998,
#    787532,
#    483405,
#    486994,
#    479330,
#    482405,
#    483439,
#    487537,
#    478845,
#    480895,
#    479360,
#    788611,
#    481413,
#    788629,
#    484503,
#    478885,
#    488122,
#    787650,
#    488132,
#    487632,
#    788178,
#    788179,
#    788180,
#    788181,
#    485588,
#    484578,
#    482022,
#    788712,
#    488172,
#    477933,
#    787694,
#    787697,
#    479987,
#    483059,
#    480509,
#    482558,
#    487690,
#    789783,
#    481563,
#    484132,
#    787769,
#    787771,
#    488251,
#    487229,
#    787774,
#    484165,
#    482634,
#    483661,
#    481621,
#    478042,
#    487778,
#    480613,
#    483700,
#    789891,
#    789909,
#    789919,
#    485800,
#    481712,
#    485809,
#    789975,
#    487398,
#    486374,
#    487916,
#    485878,
#    481273],
#   'lots': [{'company_id': 137,
#     'fields': [{'name': 'grouping_unit_01', 'values': ['47', '30']}]}],
#   'areas': [164]},
#  'is_canary': False,
#  'phone': '77663540',
#  'created_at': '2025-04-27',
#  'updated_at': '2025-04-27'}

# %%
def listar_usuarios_nax(token: str, corporate_id: int):
    url = f"https://beta-api.naxsolutions.com/api/v1/corporates/{corporate_id}/users"
    headers = {
        "Authorization": f"Bearer {token}"
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        return response.json()  # Devuelve la lista de usuarios
    else:
        print(f"❌ Error {response.status_code}: {response.text}")
        return []

# %%
usuarios = listar_usuarios_nax(token=token, corporate_id=57)

# %%
# Convertir los usuarios en DataFrame
df_usuarios = pd.DataFrame(usuarios["items"])

# Mostrar las primeras filas
df_usuarios['limits'][2]
#df_usuarios
# Out:
# {'apps': ['SMART_MODELS',
#   'INSPECTIONS',
#   'ANALYTICS',
#   'VARIABLE_MAPS',
#   'SMART_SAMPLINGS'],
#  'lots': [{'fields': [{'name': 'grouping_unit_01', 'values': ['30', '47']}],
#    'company_id': 137}],
#  'areas': [164],
#  'plots': [487943,
#   483336,
#   483849,
#   484877,
#   789010,
#   790035,
#   486935,
#   483867,
#   483361,
#   485923,
#   485412,
#   478765,
#   487981,
#   787503,
#   487985,
#   487998,
#   787532,
#   483405,
#   486994,
#   479330,
#   482405,
#   483439,
#   487537,
#   478845,
#   480895,
#   479360,
#   788611,
#   481413,
#   788629,
#   484503,
#   478885,
#   488122,
#   787650,
#   488132,
#   487632,
#   788178,
#   788179,
#   788180,
#   788181,
#   485588,
#   484578,
#   482022,
#   788712,
#   488172,
#   477933,
#   787694,
#   787697,
#   479987,
#   483059,
#   480509,
#   482558,
#   487690,
#   789783,
#   481563,
#   484132,
#   787769,
#   787771,
#   488251,
#   487229,
#   787774,
#   484165,
#   482634,
#   483661,
#   481621,
#   478042,
#   487778,
#   480613,
#   483700,
#   789891,
#   789909,
#   789919,
#   485800,
#   481712,
#   485809,
#   789975,
#   487398,
#   486374,
#   487916,
#   485878,
#   481273],
#  'companies': [137]}
