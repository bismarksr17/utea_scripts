# %%
import pandas as pd
import os

# %%
# colocar aqui la ruta de los archivos
path = r'C:\Documents\_TEMP\New folder'
contenido = os.listdir(path)
rutas =[]
i = 0
for name in contenido:
    ruta = path + '/' + name
    rutas.append(ruta)
    i+=1

print('SE ENCONTRARON ' + str(i) + ' INFORMES')
print(len(rutas), 'INFORMES')
# Out:
# SE ENCONTRARON 4 INFORMES
# 4 INFORMES

# %%
rutas_name = [ i.split('/')[-1] for i in rutas]

# %%
rutas_name
# Out:
# ['PLANO_1.pdf', 'PLANO_2.pdf', 'PLANO_3.pdf', 'PLANO_4.pdf']

# %%
# CONEXION A GOOGLE DRIVE
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
gauth = GoogleAuth()
gauth.LocalWebserverAuth() # client_secrets.json need to be in the same directory as the script
drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=590569475424-p6rmonetvvj1ea39ser57a4f3r7e70dh.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %%
len(dic_files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 len(dic_files)
#
# NameError: name 'dic_files' is not defined

# %%
dic_files = {}
for i in rutas_name:
    cod = i.split('_')[-1].split('.')[0]
    dic_files[int(cod)] = i

# %%
dic_files
# Out:
# {1: 'PLANO_1.pdf', 2: 'PLANO_2.pdf', 3: 'PLANO_3.pdf', 4: 'PLANO_4.pdf'}

# %%
# CARGAR LOS PDFS A GOOGLE DRIVE
dic_urls = {}
# View all folders and file in your Google Drive
fileList = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file in fileList:
  #print('Title: %s, ID: %s' % (file['title'], file['id']))
  # Get the folder ID that you want
  if(file['title'] == "PLANOS_ESTIMATIVAS"):
      fileID = file['id']

for file in dic_files:
    file1 = drive.CreateFile({"mimeType": "application/pdf", "parents": [{"kind": "drive#fileLink", "id": fileID}]})
    file1['title'] = dic_files[file]
    file1.SetContentFile(path + '/' + dic_files[file])
    file1.Upload() # Upload the file.
    print('Created file %s with mimeType %s' % (file1['title'], file1['mimeType']))
    permission = file1.InsertPermission({
                        'type': 'anyone',
                        'value': 'anyone',
                        'role': 'reader'})
    dic_urls[file] = file1['alternateLink']
dic_urls
print('end')
# Out:
# Created file PLANO_1.pdf with mimeType application/pdf
# Created file PLANO_2.pdf with mimeType application/pdf
# Created file PLANO_3.pdf with mimeType application/pdf
# Created file PLANO_4.pdf with mimeType application/pdf
# end

# %%
dic_urls
# Out:
# {1: 'https://drive.google.com/file/d/1Yb9RhWqOo2i6kB3C1auVNu1g034a1sTX/view?usp=drivesdk',
#  2: 'https://drive.google.com/file/d/1RuXztO1FdaF5Vbc7Fq0a2iYavAcfF2FQ/view?usp=drivesdk',
#  3: 'https://drive.google.com/file/d/13DYphWHbCgQ8gxxh1SmN-XSW4FmXkTQl/view?usp=drivesdk',
#  4: 'https://drive.google.com/file/d/1wLFBc2S6imlfYS3qsycODAtagmZX3iTt/view?usp=drivesdk'}

# %%
# Convertir el diccionario en un DataFrame de pandas
df = pd.DataFrame(list(dic_urls.items()), columns=['ID', 'URL'])

# %%
df
# Out:
#    ID                                                URL
# 0   1  https://drive.google.com/file/d/1Yb9RhWqOo2i6k...
# 1   2  https://drive.google.com/file/d/1RuXztO1FdaF5V...
# 2   3  https://drive.google.com/file/d/13DYphWHbCgQ8g...
# 3   4  https://drive.google.com/file/d/1wLFBc2S6imlfY...

# %%
# Exportar el DataFrame a un archivo Excel
output_path = r'C:\Users\Usuario\Desktop\PYTHON\utea_scripts\notificaciones_whastapp\enlaces_cosecha.xlsx'
df.to_excel(output_path, index=False)
