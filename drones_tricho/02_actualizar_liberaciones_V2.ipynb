# %%
import sys
sys.path.append('..')

import os
import geopandas as gpd
import pandas as pd
from shapely import wkb
from geopandas import sjoin
import binascii

from sqlalchemy import create_engine, text
from sqlalchemy.exc import SQLAlchemyError

from utilities_amigocloud import AmigocloudFunctions

# %%
from config import RUTA_UNIDAD_ONE_DRIVE
from config import RUTA_LOCAL_ONE_DRIVE
from config import API_AMIGOCLOUD_TOKEN_ADM
from config import POSTGRES_UTEA

ID_PROYECTO = 33457
RUTA_COMPLETA = os.path.join(RUTA_UNIDAD_ONE_DRIVE, RUTA_LOCAL_ONE_DRIVE)

# %%
ID_PROYECTO
# Out:
# 33457

# %%
amigocloud = AmigocloudFunctions(token=API_AMIGOCLOUD_TOKEN_ADM)
amigocloud

# %%
def obtener_engine():
    return create_engine(
        f"postgresql+psycopg2://{POSTGRES_UTEA['USER']}:{POSTGRES_UTEA['PASSWORD']}@{POSTGRES_UTEA['HOST']}:{POSTGRES_UTEA['PORT']}/{POSTGRES_UTEA['DATABASE']}"
    )

def obtenet_parte_diario_amigocloud():
    query = 'select * from dataset_342996 order by idd'
    select = amigocloud.ejecutar_query_sql(ID_PROYECTO, query, 'get')
    return select['data']

def mover_parte_a_clon_amigocloud(idd):
    query = f'INSERT INTO dataset_348546 (fecha_registro, amigo_id, propiedad, piloto_1, piloto_2, lote, area, hora_inicio, hora_fin,\
            institucion, labor, temperatura, viento, humedad, dron, obs, canhero, idd, ubicaciones) SELECT fecha_registro,\
            amigo_id, propiedad, piloto_1, piloto_2, lote, area, hora_inicio, hora_fin, institucion, labor, temperatura, viento, \
            humedad, dron, obs, canhero, idd, ubicaciones FROM dataset_342996 WHERE idd = {idd}'
    result1 = amigocloud.ejecutar_query_sql(ID_PROYECTO, query, 'post')
    print(result1)
    query = f'DELETE FROM dataset_342996 WHERE idd = {idd}'
    result2 = amigocloud.ejecutar_query_sql(ID_PROYECTO, query, 'post')
    return result2

def mover_lote_a_clon_amigocloud(id):
    query = f'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,\
    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,\
    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = {id}'
    result1 = amigocloud.ejecutar_query_sql(ID_PROYECTO, query, 'post')
    print(result1)
    query = f'DELETE FROM dataset_345601 WHERE id = {id}'
    result2 = amigocloud.ejecutar_query_sql(ID_PROYECTO, query, 'post')
    return result2

def obtenet_parte_diario_db_planificado():
    engine = obtener_engine()
    try:
        query = """
            SELECT * FROM drones_control_bio.parte_diario_ctrl_bio WHERE estado = 'PLANIFICADO'
        """
        gdf = gpd.read_postgis(query, engine, geom_col='geom')
        return gdf
    except Exception as e:
        print(f"❌ Error en la consulta: {e}")
        return gpd.GeoDataFrame()
    return None

def obtenet_parte_diario_db_ejecutado():
    engine = obtener_engine()
    try:
        query = """
            SELECT * FROM drones_control_bio.parte_diario_ctrl_bio WHERE estado = 'EJECUTADO'
        """
        gdf = gpd.read_postgis(query, engine, geom_col='geom')
        return gdf
    except Exception as e:
        print(f"❌ Error en la consulta: {e}")
        return gpd.GeoDataFrame()
    return None

def convertir_json_a_gdf_utm20(json_data):
    datos_con_geom = [d for d in json_data if d.get('ubicaciones')]
    geometrias = []
    for item in datos_con_geom:
        hex_wkb = item['ubicaciones']
        try:
            wkb_bytes = binascii.unhexlify(hex_wkb)
            geom = wkb.loads(wkb_bytes)
        except Exception as e:
            print(f"Error con item {item.get('idd')}: {e}")
            geom = None
        geometrias.append(geom)

    df = pd.DataFrame(datos_con_geom)
    gdf = gpd.GeoDataFrame(df, geometry=geometrias, crs="EPSG:4326")
    gdf_utm = gdf.to_crs("EPSG:32720")
    return gdf_utm

def validar_puntos_parte_fuera(puntos, lotes):    
    # Extraer la geometría multipunto
    multipunto = puntos.geometry.iloc[0]
    # Crear un GeoDataFrame con cada punto por separado
    gdf_puntos = gpd.GeoDataFrame(geometry=[p for p in multipunto.geoms], crs="EPSG:32720")
    # Verifica para cada punto si intersecta algún polígono
    gdf_puntos["intersecta"] = gdf_puntos.geometry.apply(
        lambda punto: lotes.intersects(punto).any()
    )
    puntos_fuera = gdf_puntos[~gdf_puntos["intersecta"]]
    if len(puntos_fuera) > 0:
        return True
    else:
        return False
    return None

def validar_puntos_en_propiedad(gdf_parte_db, gdf_parte_amigocloud):
    gdf_intersect_directo = gpd.sjoin(gdf_parte_db, gdf_parte_amigocloud, how="inner", predicate="intersects")
    count_props = len(list(set(gdf_intersect_directo['unidad_01'])))
    if count_props == 1:
        return True
    else:
        return False
    return None

def validar_parte_diario_amigocloud_nulls(parte_diario):
    columnas_a_eliminar = ['propiedad', 'lote', 'area', 'institucion', 'obs', 'canhero']
    parte_diario = parte_diario.drop(columns=columnas_a_eliminar)
    # Lista columnas con valores nulos en la fila
    null_columns = parte_diario.isnull().any()
    null_fields = null_columns[null_columns].index.tolist()
    if len(null_fields) > 0:
        return True
    else:
        return False
    return None

def actualizar_estado_ejecutado(producto, dosis, fecha_reg, semana, temp, viento, humedad, cod_dron, piloto_1, piloto_2, idd, hora_inicio, hora_fin, estado, id):
    engine = obtener_engine()
    try:
        with engine.connect() as connection:
            query = text("""
                UPDATE drones_control_bio.parte_diario_ctrl_bio
                    SET
                    producto = :producto,
                    dosis = :dosis,
                    fecha = :fecha_reg,
                    semana = :semana,
                    temp = :temp,
                    viento = :viento,
                    humedad = :humedad,
                    cod_dron = :cod_dron,
                    piloto_1 = :piloto_1,
                    piloto_2 = :piloto_2,
                    idd = :idd,
                    hora_ini = :hora_inicio,
                    hora_fin = :hora_fin,
                    estado = :estado
                    WHERE id = :id
            """)
            connection.execute(query, {
                "producto": producto,
                "dosis": dosis,
                "fecha_reg": fecha_reg,
                "semana": semana,
                "temp": temp,
                "viento": viento,
                "humedad": humedad,
                "cod_dron": cod_dron,
                "piloto_1": piloto_1,
                "piloto_2": piloto_2,
                "idd": idd,
                "hora_inicio": hora_inicio,
                "hora_fin": hora_fin,
                "estado": estado,
                "id": id})
            connection.commit()
            print(f"✅ Estado actualizado a 'EJECUTADO' para IDs: {id}")
    except SQLAlchemyError as e:
        print(f"❌ Error al actualizar estado: {e}")

# %%
parte_diario_amigocloud = obtenet_parte_diario_amigocloud()
gdf_parte_diario_amigocloud = convertir_json_a_gdf_utm20(parte_diario_amigocloud)
gdf_parte_diario_db = obtenet_parte_diario_db_planificado()

# %%
for i in range(len(gdf_parte_diario_amigocloud)):
    parte_diario_amigocloud = gdf_parte_diario_amigocloud.iloc[[i]]
    idd_aux = parte_diario_amigocloud['idd'].iloc[0]
    parte_diario_amigocloud
    
    parte_diario_nulls = validar_parte_diario_amigocloud_nulls(parte_diario_amigocloud)
    puntos_fuera = validar_puntos_parte_fuera(parte_diario_amigocloud, gdf_parte_diario_db)
    puntos_en_propiedad = validar_puntos_en_propiedad(gdf_parte_diario_db, parte_diario_amigocloud)

    if parte_diario_nulls == True:
        print(f'El parte diario de AmigoCloud idd: {idd_aux} tiene campos nulos')
        continue
    elif puntos_fuera == True:
        print(f'El parte diario de AmigoCloud idd: {idd_aux} tiene puntos que no coinsiden con algun lote')
        continue
    elif puntos_en_propiedad == False:
        print(f'El parte diario de AmigoCloud idd: {idd_aux} tiene puntos en mas de una propiedad')
        continue
    
    gdf_intersect = gpd.sjoin(parte_diario_amigocloud, gdf_parte_diario_db, how="inner", predicate="intersects")
    idd = gdf_intersect['idd_left'].iloc[0]
    id_lotes_ejecutado = list(gdf_intersect['id'])

    for i, row in gdf_intersect.iterrows():
        id = row['id']
        producto = row['producto_left']
        dosis = row['dosis_left']
        fecha_reg = pd.to_datetime(row['fecha_registro'])
        semana = fecha_reg.isocalendar().week
        temp = row['temperatura']
        viento = row['viento_left']
        humedad = row['humedad_left']
        cod_dron = row['dron']
        piloto_1 = row['piloto_1_left']
        piloto_2 = row['piloto_2_left']
        idd = row['idd_left']
        hora_inicio = pd.to_datetime(row['hora_inicio'])
        hora_fin = pd.to_datetime(row['hora_fin_left'])
        estado = 'EJECUTADO'
        actualizar_estado_ejecutado(producto, dosis, fecha_reg, semana, temp, viento, humedad, cod_dron, piloto_1, piloto_2, idd, hora_inicio, hora_fin, estado, id)

    result = mover_parte_a_clon_amigocloud(idd)
    gdf_lotes_planificados = obtenet_parte_diario_db_ejecutado()
    lista_ids = list(gdf_lotes_planificados['id'])
    for i in lista_ids:
        result = mover_lote_a_clon_amigocloud(i)
        print(result)
# Out:
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 62
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 49
# {'query': 'INSERT INTO dataset_348546 (fecha_registro, amigo_id, propiedad, piloto_1, piloto_2, lote, area, hora_inicio, hora_fin,            institucion, labor, temperatura, viento, humedad, dron, obs, canhero, idd, ubicaciones) SELECT fecha_registro,            amigo_id, propiedad, piloto_1, piloto_2, lote, area, hora_inicio, hora_fin, institucion, labor, temperatura, viento,             humedad, dron, obs, canhero, idd, ubicaciones FROM dataset_342996 WHERE idd = 578', 'count': 1, 'amigo_ids': ['c53a86fc6f6845318fdf54d61cc8c011']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 62', 'count': 1, 'amigo_ids': ['89669d6b3b25440bad83fa5577b820ed']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 62', 'count': 1, 'amigo_ids': ['89669d6b3b25440bad83fa5577b820ed']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 49', 'count': 1, 'amigo_ids': ['54949b57a5e448ee986e9ab689c6e4d8']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 49', 'count': 1, 'amigo_ids': ['54949b57a5e448ee986e9ab689c6e4d8']}
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 56
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 57
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 60
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 58
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 51
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 50
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 54
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 48
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 55
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 59
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 52
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 61
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 53
# {'query': 'INSERT INTO dataset_348546 (fecha_registro, amigo_id, propiedad, piloto_1, piloto_2, lote, area, hora_inicio, hora_fin,            institucion, labor, temperatura, viento, humedad, dron, obs, canhero, idd, ubicaciones) SELECT fecha_registro,            amigo_id, propiedad, piloto_1, piloto_2, lote, area, hora_inicio, hora_fin, institucion, labor, temperatura, viento,             humedad, dron, obs, canhero, idd, ubicaciones FROM dataset_342996 WHERE idd = 579', 'count': 1, 'amigo_ids': ['0d0f9d005a344460842bb203b9fcebb4']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 51', 'count': 1, 'amigo_ids': ['d450b969e68d4b8994822e79f45f1715']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 51', 'count': 1, 'amigo_ids': ['d450b969e68d4b8994822e79f45f1715']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 50', 'count': 1, 'amigo_ids': ['cc8b1c31b58b469ba312492d7bd2a5d2']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 50', 'count': 1, 'amigo_ids': ['cc8b1c31b58b469ba312492d7bd2a5d2']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 54', 'count': 1, 'amigo_ids': ['cc16a91aede84f78acab47c7e6f3e967']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 54', 'count': 1, 'amigo_ids': ['cc16a91aede84f78acab47c7e6f3e967']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 48', 'count': 1, 'amigo_ids': ['dce1df1245624201bf1f1832c548fb80']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 48', 'count': 1, 'amigo_ids': ['dce1df1245624201bf1f1832c548fb80']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 52', 'count': 1, 'amigo_ids': ['63d5bd236f7d4e458329c8f6b9542f27']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 52', 'count': 1, 'amigo_ids': ['63d5bd236f7d4e458329c8f6b9542f27']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 62', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 62', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 49', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 49', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 56', 'count': 1, 'amigo_ids': ['28c53f25ec6d4a3ab0f346154735f169']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 56', 'count': 1, 'amigo_ids': ['28c53f25ec6d4a3ab0f346154735f169']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 57', 'count': 1, 'amigo_ids': ['d88e750564c745e19bca5155dc3f9f99']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 57', 'count': 1, 'amigo_ids': ['d88e750564c745e19bca5155dc3f9f99']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 60', 'count': 1, 'amigo_ids': ['9788bf66583e43cbb1d798a9de6c1a7c']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 60', 'count': 1, 'amigo_ids': ['9788bf66583e43cbb1d798a9de6c1a7c']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 58', 'count': 1, 'amigo_ids': ['9eb1757b57fc461fa942b9acda87fc41']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 58', 'count': 1, 'amigo_ids': ['9eb1757b57fc461fa942b9acda87fc41']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 55', 'count': 1, 'amigo_ids': ['e499ebd09d8e4bd0841f5f920dd08872']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 55', 'count': 1, 'amigo_ids': ['e499ebd09d8e4bd0841f5f920dd08872']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 59', 'count': 1, 'amigo_ids': ['f94b2129da764318b71220214164ff3c']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 59', 'count': 1, 'amigo_ids': ['f94b2129da764318b71220214164ff3c']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 61', 'count': 1, 'amigo_ids': ['54297d38eb4a4520bb7bc8235d7dfe68']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 61', 'count': 1, 'amigo_ids': ['54297d38eb4a4520bb7bc8235d7dfe68']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 53', 'count': 1, 'amigo_ids': ['57de7299bb72468aa5a2b12333aaa0dd']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 53', 'count': 1, 'amigo_ids': ['57de7299bb72468aa5a2b12333aaa0dd']}
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 42
# {'query': 'INSERT INTO dataset_348546 (fecha_registro, amigo_id, propiedad, piloto_1, piloto_2, lote, area, hora_inicio, hora_fin,            institucion, labor, temperatura, viento, humedad, dron, obs, canhero, idd, ubicaciones) SELECT fecha_registro,            amigo_id, propiedad, piloto_1, piloto_2, lote, area, hora_inicio, hora_fin, institucion, labor, temperatura, viento,             humedad, dron, obs, canhero, idd, ubicaciones FROM dataset_342996 WHERE idd = 580', 'count': 1, 'amigo_ids': ['89cee9f9bdde4b38af35b7ca2fa6ee10']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 51', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 51', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 50', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 50', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 54', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 54', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 48', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 48', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 52', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 52', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 42', 'count': 1, 'amigo_ids': ['e99af795ce4c49b49737de57fdc98d04']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 42', 'count': 1, 'amigo_ids': ['e99af795ce4c49b49737de57fdc98d04']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 62', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 62', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 49', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 49', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 56', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 56', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 57', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 57', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 60', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 60', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 58', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 58', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 55', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 55', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 59', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 59', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 61', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 61', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 53', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 53', 'count': 0}
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 47
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 46
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 45
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 43
# ✅ Estado actualizado a 'EJECUTADO' para IDs: 44
# {'query': 'INSERT INTO dataset_348546 (fecha_registro, amigo_id, propiedad, piloto_1, piloto_2, lote, area, hora_inicio, hora_fin,            institucion, labor, temperatura, viento, humedad, dron, obs, canhero, idd, ubicaciones) SELECT fecha_registro,            amigo_id, propiedad, piloto_1, piloto_2, lote, area, hora_inicio, hora_fin, institucion, labor, temperatura, viento,             humedad, dron, obs, canhero, idd, ubicaciones FROM dataset_342996 WHERE idd = 581', 'count': 1, 'amigo_ids': ['c70cabe26aa34a58b2fdaca4e0630e79']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 51', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 51', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 50', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 50', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 54', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 54', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 48', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 48', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 52', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 52', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 42', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 42', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 47', 'count': 1, 'amigo_ids': ['43bd8c139fb742cf9632a47b3187b538']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 47', 'count': 1, 'amigo_ids': ['43bd8c139fb742cf9632a47b3187b538']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 45', 'count': 1, 'amigo_ids': ['c0fa73deb3ef4c0f84fd522c402cfe6f']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 45', 'count': 1, 'amigo_ids': ['c0fa73deb3ef4c0f84fd522c402cfe6f']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 44', 'count': 1, 'amigo_ids': ['52713578c91c42c7870c872ed9402e2a']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 44', 'count': 1, 'amigo_ids': ['52713578c91c42c7870c872ed9402e2a']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 62', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 62', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 49', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 49', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 56', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 56', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 57', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 57', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 60', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 60', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 58', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 58', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 55', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 55', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 59', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 59', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 61', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 61', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 53', 'count': 0}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 53', 'count': 0}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 46', 'count': 1, 'amigo_ids': ['c1676589726146d8a7d154277e7b87a9']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 46', 'count': 1, 'amigo_ids': ['c1676589726146d8a7d154277e7b87a9']}
# {'query': 'INSERT INTO dataset_348547 (fecha_registro, amigo_id, id, unidad_01, unidad_02, unidad_03, unidad_04,    unidad_05, area, origen, dias, os, geometry) SELECT fecha_registro, amigo_id, id, unidad_01, unidad_02,    unidad_03, unidad_04, unidad_05, area, origen, dias, os, geometry FROM dataset_345601 WHERE id = 43', 'count': 1, 'amigo_ids': ['7493f5419647435eb66834cc80551ad4']}
# {'query': 'DELETE FROM dataset_345601 WHERE id = 43', 'count': 1, 'amigo_ids': ['7493f5419647435eb66834cc80551ad4']}
