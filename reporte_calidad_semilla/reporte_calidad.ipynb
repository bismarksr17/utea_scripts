# %%
import pandas as pd

# %%
# ruta de carpera donde estan las llaves
ruta = open('../ruta.txt')
ruta = ruta.readlines()[0]
ruta
# Out:
# 'C:\\Documents\\OneDrive - Ingenio Azucarero Guabira S.A\\_DATOS_PYTHON'

# %%
path_xlsx = r'C:\Documents\OneDrive - Ingenio Azucarero Guabira S.A\UTEA_2024\CALIDAD DE SIEMBRA\DATOS\_LA ESTACADA - OLGUITA.xlsx'

# %%
df = pd.read_excel(path_xlsx)
df
# Out:
#    PROPIEDAD:          LA ESTACADA  Unnamed: 2          LOTE:         A5  \
# 0      FECHA:  2024-02-20 00:00:00         NaN        CLICLO:       HOJA
# 1         NaN                  NaN         NaN            NaN        NaN
# 2     MUESTRA          TOTAL YEMAS  PERFORADAS  ENRAIZAMIENTO  BROTACION
# 3           1                  267           8             15          9
# 4           2                  279           0              2         34
# 5           3                  296           2              7         34
# 6           4                  254           5              3         15
# 7           5                  266           0              0         27
# 8           6                  279           1              9         40
# 9           7                  262           9              5         35
# 10          8                  265          19             19         23
# 11          9                  303           3              0         49
# ...
