# %%
import pandas as pd
import os
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_19976\3026406390.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# colocar aqui la ruta de los archivos
path = r'G:\BISMARK\_TEMP\PLANOS_COSECHA'
contenido = os.listdir(path)
rutas =[]
i = 0
for name in contenido:
    ruta = path + '/' + name
    rutas.append(ruta)
    i+=1

print('SE ENCONTRARON ' + str(i) + ' INFORMES')
print(len(rutas), 'INFORMES')
# Out:
# SE ENCONTRARON 230 INFORMES
# 230 INFORMES

# %%
rutas_name = [ i.split('/')[-1] for i in rutas]

# %%
rutas_name
# Out:
# ['PLANO_1006.pdf',
#  'PLANO_1014.pdf',
#  'PLANO_1025.pdf',
#  'PLANO_1043.pdf',
#  'PLANO_1084.pdf',
#  'PLANO_1091.pdf',
#  'PLANO_1099.pdf',
#  'PLANO_110.pdf',
#  'PLANO_1115.pdf',
#  'PLANO_112.pdf',
#  'PLANO_1121.pdf',
#  'PLANO_113.pdf',
#  'PLANO_1139.pdf',
#  'PLANO_114.pdf',
#  'PLANO_1140.pdf',
#  'PLANO_1146.pdf',
#  'PLANO_1158.pdf',
#  'PLANO_1174.pdf',
#  'PLANO_1184.pdf',
#  'PLANO_1193.pdf',
#  'PLANO_1195.pdf',
#  'PLANO_1197.pdf',
#  'PLANO_1199.pdf',
#  'PLANO_1215.pdf',
#  'PLANO_1216.pdf',
#  'PLANO_123.pdf',
#  'PLANO_1252.pdf',
#  'PLANO_1260.pdf',
#  'PLANO_1294.pdf',
#  'PLANO_1295.pdf',
#  'PLANO_1306.pdf',
#  'PLANO_1339.pdf',
#  'PLANO_1352.pdf',
#  'PLANO_136.pdf',
#  'PLANO_1370.pdf',
#  'PLANO_1375.pdf',
#  'PLANO_1382.pdf',
#  'PLANO_1384.pdf',
#  'PLANO_1397.pdf',
#  'PLANO_14.pdf',
#  'PLANO_1404.pdf',
#  'PLANO_1406.pdf',
#  'PLANO_1416.pdf',
#  'PLANO_1417.pdf',
#  'PLANO_145.pdf',
#  'PLANO_1469.pdf',
#  'PLANO_1472.pdf',
#  'PLANO_1480.pdf',
# ...

# %%
# CONEXION A GOOGLE DRIVE
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
gauth = GoogleAuth()
gauth.LocalWebserverAuth() # client_secrets.json need to be in the same directory as the script
drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=1096764895697-57btfmtn7rdejufct5qq4j9mi61j0unl.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %%
len(dic_files)
# Out:
# 230

# %%
dic_files = {}
for i in rutas_name:
    cod = i.split('_')[-1].split('.')[0]
    dic_files[int(cod)] = i

# %%
# CARGAR LOS PDFS A GOOGLE DRIVE
dic_urls = {}
# View all folders and file in your Google Drive
fileList = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file in fileList:
  #print('Title: %s, ID: %s' % (file['title'], file['id']))
  # Get the folder ID that you want
  if(file['title'] == "PLANOS_COSECHA"):
      fileID = file['id']

for file in dic_files:
    file1 = drive.CreateFile({"mimeType": "application/pdf", "parents": [{"kind": "drive#fileLink", "id": fileID}]})
    file1['title'] = dic_files[file]
    file1.SetContentFile(path + '/' + dic_files[file])
    file1.Upload() # Upload the file.
    print('Created file %s with mimeType %s' % (file1['title'], file1['mimeType']))
    permission = file1.InsertPermission({
                        'type': 'anyone',
                        'value': 'anyone',
                        'role': 'reader'})
    dic_urls[file] = file1['alternateLink']
dic_urls
print('end')
# Out:
# Created file PLANO_1006.pdf with mimeType application/pdf
# Created file PLANO_1014.pdf with mimeType application/pdf
# Created file PLANO_1025.pdf with mimeType application/pdf
# Created file PLANO_1043.pdf with mimeType application/pdf
# Created file PLANO_1084.pdf with mimeType application/pdf
# Created file PLANO_1091.pdf with mimeType application/pdf
# Created file PLANO_1099.pdf with mimeType application/pdf
# Created file PLANO_110.pdf with mimeType application/pdf
# Created file PLANO_1115.pdf with mimeType application/pdf
# Created file PLANO_112.pdf with mimeType application/pdf
# Created file PLANO_1121.pdf with mimeType application/pdf
# Created file PLANO_113.pdf with mimeType application/pdf
# Created file PLANO_1139.pdf with mimeType application/pdf
# Created file PLANO_114.pdf with mimeType application/pdf
# Created file PLANO_1140.pdf with mimeType application/pdf
# Created file PLANO_1146.pdf with mimeType application/pdf
# ...

# %%
dic_urls
# Out:
# {1006: 'https://drive.google.com/file/d/1X-pz2emh6uTd9VA2DaZvw8b50DAR2BPR/view?usp=drivesdk',
#  1014: 'https://drive.google.com/file/d/1eioLpWEqEbmPvR1sPVkK1LG-J3IBN61w/view?usp=drivesdk',
#  1025: 'https://drive.google.com/file/d/1ijYJUDiGZgXbzEsDx_LZ1-LIAay_xcsB/view?usp=drivesdk',
#  1043: 'https://drive.google.com/file/d/1rt73LvXr6fxUB0Gov8WeKNakCHkGjbXS/view?usp=drivesdk',
#  1084: 'https://drive.google.com/file/d/1l1FdNDKhsKodkGTtLJTHh-CGhpvvx6eZ/view?usp=drivesdk',
#  1091: 'https://drive.google.com/file/d/1MjcAOBvYXp9QZiYYcY1HKSW9bC4xW2dv/view?usp=drivesdk',
#  1099: 'https://drive.google.com/file/d/1Irt-mXuqq8r46Noi7W9adExBx3TDqxv2/view?usp=drivesdk',
#  110: 'https://drive.google.com/file/d/1HTvGYX1iPYH_7QSDVRjUmKpjd-EmzQWV/view?usp=drivesdk',
#  1115: 'https://drive.google.com/file/d/1tV4EacdM5wsvNqmFDfJ18_esZWkWZQ8-/view?usp=drivesdk',
#  112: 'https://drive.google.com/file/d/1OF80utwgwKHwXWUSYrfP92Ts257C8KmM/view?usp=drivesdk',
# ...

# %%
# Convertir el diccionario en un DataFrame de pandas
df = pd.DataFrame(list(dic_urls.items()), columns=['ID', 'URL'])

# %%
# Exportar el DataFrame a un archivo Excel
output_path = r'C:\Users\Usuario\Desktop\PYTHON\utea_scripts\notificaciones_whastapp\enlaces_cosecha.xlsx'
df.to_excel(output_path, index=False)
