# %%
import sys
sys.path.append('../..')
from sqlalchemy import create_engine, MetaData, Table, text

import asyncio
import httpx
from datetime import datetime, timedelta
import time
import pandas as pd

from config import POSTGRES_UTEA

USER_DB = POSTGRES_UTEA['USER']
PASS_DB = POSTGRES_UTEA['PASSWORD']
HOST_DB = POSTGRES_UTEA['HOST']
PORT_DB = POSTGRES_UTEA['PORT']
NAME_DB = POSTGRES_UTEA['DATABASE']

ENGINE = create_engine(f'postgresql+psycopg://{USER_DB}:{PASS_DB}@{HOST_DB}:{PORT_DB}/{NAME_DB}')
VIAJES = 500
PROMEDIO_LLEGADAS = 500

# %%
metadata = MetaData()
msj_whatsapp_tbl = Table("msj_whatsapp", metadata, autoload_with=ENGINE, schema="notificaciones_wsp")

# %%
# 1️⃣ Función para consultar API con manejo de errores
async def extraer_datos(endpoint, fecha_ini, fecha_fin):
    url = f"http://10.1.0.103:9080/Utea/{endpoint}"
    params = {
        "pStrFecIni": fecha_ini,
        "pStrFecFin": fecha_fin,
    }
    timeout = httpx.Timeout(10.0)
    try:
        async with httpx.AsyncClient(timeout=timeout) as client:
            response = await client.get(url, params=params)
            if response.status_code == 200:
                now = datetime.now()
                formatted_now = now.strftime('%d/%m/%Y %H:%M:%S')
                print(formatted_now + " - GET: " + endpoint)
                return response.json()
            else:
                print(f"⚠️ Error {response.status_code} en {endpoint}")
                return None
    except httpx.RequestError as e:
        print(f"❌ Error de conexión con {endpoint}: {e}")
        return None

# %%
def es_hora_madrugada():
    ahora = datetime.now().time()
    return (ahora.hour >= 0 and ahora.hour < 7)

def calcular_horas_espera(df_tcb):
    df = df_tcb.copy()
    # elimina todos los registro sin datos de fechaDocum y HoraDocum
    #df = df.dropna(subset=['canero'])
    df = df[df['dateDocum'] != '0000-00-00']
    #extrae la hora para FECHA DE INICIO
    df['horaDocum'] = df['horaDocum'].str.split('T').str[1]
    # concatena fecha y hora
    df['fecha_inicio'] = df['dateDocum'] + ' ' + df['horaDocum']
    # convierte la columna a tipo datetime
    df['fecha_inicio'] = pd.to_datetime(df['fecha_inicio'])
    #extraer la hora para FECHA DE FIN
    df['startTime'] = df['startTime'].str.split('T').str[1]
    # concatena fecha y hora
    df['fecha_fin'] = df['startDate'] + ' ' + df['startTime']
    # convierte la columna a tipo datetime
    df['fecha_fin'] = pd.to_datetime(df['fecha_fin'])
    #calcula la diferencia
    df['espera'] = (df['fecha_fin'] - df['fecha_inicio']).dt.total_seconds() / 3600
    #retorn la media
    return df['espera'].mean()

def definir_trapiche(df):
    # extrae la hora
    df['solo_hora'] = df['hora'].str.split('T').str[1]
    # concatena fecha y hora
    df['fecha_hora'] = df['fecha'] + ' ' + df['solo_hora']
    # convierte la columna a tipo datetime
    df['fecha_hora'] = pd.to_datetime(df['fecha_hora'])
    # obtiene la fecha y hora actual
    hora_actual = datetime.now()
    # calcula una hora antes
    una_hora_antes = hora_actual - timedelta(hours=1)
    # filtra los resgistros de la ultima hora
    df_ultima_hora = df[(df['fecha_hora'] >= una_hora_antes) & (df['fecha_hora'] <= hora_actual)]
    trapiches = list(set(df_ultima_hora['trapiche']))
    trapiches = [int(i) for i in trapiches]
    if len(trapiches) == 0:
        return 0
    elif 1 in trapiches and 2 in trapiches:
        return 3
    elif 1 in trapiches:
        return 1
    elif 2 in trapiches:
        return 2
    return 0

def get_horarios():
    try:
        df = pd.read_sql("SELECT * FROM datos_iag.horarios", ENGINE)
        return df
    except Exception as e:
        print("❌ Error al consultar PostgreSQL:", e)
        return pd.DataFrame()

def crear_alerta(datos):
    global VIAJES
    global PROMEDIO_LLEGADAS
    
    viajes_disponibles = datos['viajes_disponibles']
    promedio_llegada_viajes = datos['promedio_llegada_viajes']
    
    if viajes_disponibles > 200:
        if VIAJES <= 200:
            VIAJES = viajes_disponibles
            return True
    elif viajes_disponibles > 120:
        if VIAJES <= 120:
            VIAJES = viajes_disponibles
            return True
    elif viajes_disponibles >= 20 and viajes_disponibles <= 120:
        VIAJES = viajes_disponibles
        return False
    elif viajes_disponibles < 20:
        if VIAJES >= 20:
            VIAJES = viajes_disponibles
            return True
    elif promedio_llegada_viajes >= 8:
        if PROMEDIO_LLEGADAS < 8:
            PROMEDIO_LLEGADAS = promedio_llegada_viajes
            return True
        else:
            PROMEDIO_LLEGADAS = promedio_llegada_viajes
            return False
    else:
        return False
    return False

def crear_mensaje(datos):
    mensaje = f'''🔴⚠️ *ALERTA* ⚠️🔴
*📅 Hora act.:* {datos['hora']}
*⚙️ Trapiches:* {datos['trapiches_estado']}
*🚛 Viajes disponibles:* {round(datos['viajes_disponibles'],2)}
*🔢 Toneladas aprox.:* {round(datos['toneladas_aprox'],2)}
*⏱️ Promedio llegada vj.:* {round(datos['promedio_llegada_viajes'],2)}
*📈 Viajes estimados:* {round(datos['viajes_estimados'],2)}
*🕰️ Total horas abas.:* {round(datos['total_horas_abastecimiento'],2)}
*⏳ Tiempo espera:* {round(datos['tiempo_espera'],2)}
*🎋 Molienda actual:* {round(datos['molienda_actual'],2)}
*📅 Planificacion actual:* {round(datos['planificacion_actual'],2)}
*🔻 Diferencia actual:* {round(datos['diferencia_actual'],2)}
*🕒 Promedio horario:* {round(datos['promedio_horario'],2)}
*🏭 Molienda segun promedio:* {round(datos['molienda_segun_promedio'],2)}
*📊 Molienda segun estimacion:* {round(datos['molienda_segun_estimacion'],2)}'''

    mario_sanchez = '75380725'
    harold_pincker = '70249286'
    me = '78194371'

    data_mensajes = {
        "fecha_registro": [datetime.now(), datetime.now(), datetime.now()],
        "cod_canero": [0, 0, 0],
        "nombre_canero": ["Mario Sanchez Romero", "Harold Pinker", "Bismark Socompi"],
        "numero_cel": [mario_sanchez, harold_pincker, me],
        "mensaje": [mensaje, mensaje, mensaje],
        "enviado": [False, False, False],
        "fecha_enviado": [None, None, None]
    }
    
    df = pd.DataFrame(data_mensajes)
    
    try:
        with ENGINE.begin() as conn:
            conn.execute(msj_whatsapp_tbl.insert(), df.to_dict(orient='records'))
        print("✅ Se ha actualizado ")
    except Exception as e:
        print("❌ Error al insertar en tabla MSJ WHASTAPP", e)
    #return df

# %%
# 2️⃣ Simulación de función de cálculo
def calcular_datos(df_playa, df_trafCamBalanza, df_molienda):

    df_horarios = get_horarios()
    if df_horarios.empty:
        return {}
    df_molienda['hora2'] = df_molienda['hora2'].astype(int)
    df_res_molienda = pd.merge(df_molienda, df_horarios[['Hora', 'Orden_Hora']], left_on='hora2', right_on='Hora', how='left')
    
    #cantidad de paquetes
    #cantidad de caña disponible
    filtro = df_playa[(df_playa['status'] == 'PL') | (df_playa['status'] == 'IN')]
    cantidad_paquetes = filtro['cantPqt'].sum()
    cana_disponible = cantidad_paquetes * 45
    
    #promedio lleganda pq
    df_playa['dateCupo'] = pd.to_datetime(df_playa['dateCupo'])
    fecha_actual = pd.Timestamp('today').normalize()
    df_actual = df_playa[(df_playa['dateCupo'] == fecha_actual) & (df_playa['status'] != 'SL')].copy()
    df_actual['Hora_Entera'] = df_actual['horaDocum'].str[11:13].astype(int)
    max_hora_ent = df_actual['Hora_Entera'].max() - 3
    filtered_df = df_actual[df_actual['Hora_Entera'] >= max_hora_ent]
    sum_cant_pqt = filtered_df['cantPqt'].sum()
    promedio_llegada_pq = sum_cant_pqt / 3
    
    #trapiches
    # trapiche1    210 tn/ha    15 paquetes
    # trapiche2    690 tn/ha    49 paquetes
    
    #horas molienda
    horas_molienda_t1 = cantidad_paquetes / 5
    horas_molienda_t2 = cantidad_paquetes / 15
    horas_molienda_total = cantidad_paquetes / (5 + 15)
    
    #total paquetes resto dia
    total_paquetes_resto_dia_t1 = promedio_llegada_pq * horas_molienda_t1
    total_paquetes_resto_dia_t2 = promedio_llegada_pq * horas_molienda_t2
    total_paquetes_resto_dia_total = promedio_llegada_pq * horas_molienda_total
    
    #toneladas
    toneladas = df_molienda['netWeight'].sum() / 1000
    
    #planificacion actual
    planificacion_actual_t1 = df_res_molienda['Orden_Hora'].max() * 210
    planificacion_actual_t2 = df_res_molienda['Orden_Hora'].max() * 690
    planificacion_actual_total = df_res_molienda['Orden_Hora'].max() * (210 + 690)
    
    #diferencia actual
    diferencia_actual_t1 = toneladas - planificacion_actual_t1
    diferencia_actual_t2 = toneladas - planificacion_actual_t2
    diferencia_actual_total = toneladas - planificacion_actual_total
    
    #orden hora
    orden_hora = 24 - df_res_molienda['Orden_Hora'].max()
    
    #toneladas promedio
    toneladas_prom = (df_molienda['netWeight'].sum() / 1000) / (24 - orden_hora)

    #total horas
    total_horas_t1 = total_paquetes_resto_dia_t1 / (5) + horas_molienda_t1
    total_horas_t2 = total_paquetes_resto_dia_t2 / (15) + horas_molienda_t2
    total_horas_total = (total_paquetes_resto_dia_total / (5 + 15)) + horas_molienda_total

    #molienda segun promedio
    molienda_s_promedio = (toneladas_prom * orden_hora) + toneladas

    #molienda segun estimado
    molienda_s_estimado_t1 = toneladas + orden_hora * 210
    molienda_s_estimado_t2 = toneladas + orden_hora * 690
    molienda_s_estimado_total = toneladas + orden_hora * (210 + 690)

    #tiempo espera
    espera =  calcular_horas_espera(df_trafCamBalanza)
    trapiches = definir_trapiche(df_molienda)

    trapiches_estado = "01 y 02"
    viajes_disponibles = float(cantidad_paquetes)
    toneladas_aprox = float(cana_disponible)
    promedio_llegada_viajes = float(promedio_llegada_pq)
    viajes_estimados = float(total_paquetes_resto_dia_total)
    total_horas_abastecimiento = float(total_horas_total)
    tiempo_espera = float(espera)
    molienda_actual = float(toneladas)
    planificacion_actual = float(planificacion_actual_total)
    diferencia_actual = float(diferencia_actual_total)
    promedio_horario = float(toneladas_prom)
    molienda_segun_promedio = float(molienda_s_promedio)
    molienda_segun_estimacion = float(molienda_s_estimado_total)
    
    if trapiches == 0:
        trapiches_estado = "Detenidos"
        viajes_estimados = 0
        total_horas_abastecimiento = 0
        planificacion_actual = 0
        diferencia_actual = 0
        molienda_segun_estimacion = 0
    elif trapiches == 1:
        trapiches_estado = "solo 01"
        viajes_estimados = float(total_paquetes_resto_dia_t1)
        total_horas_abastecimiento = float(total_horas_t1)
        planificacion_actual = float(planificacion_actual_t1)
        diferencia_actual = float(diferencia_actual_t1)
        molienda_segun_estimacion = float(molienda_s_estimado_t1)
    elif trapiches == 2:
        trapiches_estado = "solo 02"
        viajes_estimados = float(total_paquetes_resto_dia_t2)
        total_horas_abastecimiento = float(total_horas_t2)
        planificacion_actual = float(planificacion_actual_t2)
        diferencia_actual = float(diferencia_actual_t2)
        molienda_segun_estimacion = float(molienda_s_estimado_t2)
    elif trapiches == 3:
        None
        #ya esta definido al inicio
    
    dict_datos = {
        "trapiches_estado": "01 y 02",
        "viajes_disponibles": float(cantidad_paquetes),
        "toneladas_aprox": float(cana_disponible),
        "promedio_llegada_viajes": float(promedio_llegada_pq),
        "viajes_estimados": float(total_paquetes_resto_dia_total),
        "total_horas_abastecimiento": float(total_horas_total),
        "tiempo_espera": float(espera),
        "molienda_actual": float(toneladas),
        "planificacion_actual": float(planificacion_actual_total),
        "diferencia_actual": float(diferencia_actual_total),
        "promedio_horario": float(toneladas_prom),
        "molienda_segun_promedio": float(molienda_s_promedio),
        "molienda_segun_estimacion": float(molienda_s_estimado_total)
    }
    return dict_datos

# %%
# 3️⃣ Función para guardar en PostgreSQL
def actualizar_reporte(datos):
    try:
        set_clause = ", ".join([f"{key} = :{key}" for key in datos.keys()])
        datos["id"] = 1  # condición WHERE id = 1
        query = text(f"UPDATE datos_iag.reporte SET {set_clause} WHERE id = :id")

        with ENGINE.begin() as conn:
            conn.execute(query, datos)
            print("✅ Registro actualizado correctamente (SQLAlchemy)")
    except Exception as e:
        print("❌ Error al actualizar con SQLAlchemy:", e)

# %%
# 4️⃣ Función principal asíncrona
async def ciclo_principal():
    while True:
        hoy = datetime.now().strftime('%Y-%m-%d')
        ayer = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

        # Hacer todas las peticiones en paralelo
        tareas = [
            extraer_datos("ReportePlaya", ayer, hoy),
            extraer_datos("TrafCamBalanza", ayer, hoy),
            extraer_datos("Molienda", ayer if es_hora_madrugada() else hoy, ayer if es_hora_madrugada() else hoy)
        ]
        ReportePlaya, TrafCamBalanza, Molienda = await asyncio.gather(*tareas)
        # Validar que todas tengan datos antes de calcular
        if all([ReportePlaya, TrafCamBalanza, Molienda]):
            resultado = calcular_datos(
                pd.DataFrame(ReportePlaya), 
                pd.DataFrame(TrafCamBalanza), 
                pd.DataFrame(Molienda)
            )
            now = datetime.now()
            formatted_now = now.strftime('%H:%M:%S')
            resultado["hora"] = formatted_now
            
            actualizar_reporte(resultado)
            if crear_alerta(resultado):
                crear_mensaje(resultado)
                
        else:
            print("⚠️ No se pudieron obtener todos los datos. Se omite el cálculo.")
        await asyncio.sleep(300)  # espera 5 minutos

# %%
# 5️⃣ Ejecutar
if __name__ == "__main__":
    await ciclo_principal()
# Out:
# 22/06/2025 18:02:14 - GET: Molienda
# 22/06/2025 18:02:14 - GET: ReportePlaya
# 22/06/2025 18:02:14 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:07:16 - GET: Molienda
# 22/06/2025 18:07:16 - GET: ReportePlaya
# 22/06/2025 18:07:16 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:12:18 - GET: Molienda
# 22/06/2025 18:12:18 - GET: ReportePlaya
# 22/06/2025 18:12:19 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:17:21 - GET: Molienda
# 22/06/2025 18:17:21 - GET: ReportePlaya
# 22/06/2025 18:17:21 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:22:23 - GET: Molienda
# 22/06/2025 18:22:23 - GET: ReportePlaya
# 22/06/2025 18:22:23 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:27:25 - GET: Molienda
# 22/06/2025 18:27:25 - GET: ReportePlaya
# 22/06/2025 18:27:26 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:32:28 - GET: ReportePlaya
# 22/06/2025 18:32:28 - GET: TrafCamBalanza
# 22/06/2025 18:32:32 - GET: Molienda
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:37:33 - GET: Molienda
# 22/06/2025 18:37:34 - GET: ReportePlaya
# 22/06/2025 18:37:34 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:42:36 - GET: ReportePlaya
# 22/06/2025 18:42:36 - GET: TrafCamBalanza
# 22/06/2025 18:42:40 - GET: Molienda
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:47:42 - GET: Molienda
# 22/06/2025 18:47:42 - GET: ReportePlaya
# 22/06/2025 18:47:42 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:52:44 - GET: Molienda
# 22/06/2025 18:52:44 - GET: ReportePlaya
# 22/06/2025 18:52:44 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 18:57:46 - GET: Molienda
# 22/06/2025 18:57:46 - GET: ReportePlaya
# 22/06/2025 18:57:46 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:02:48 - GET: Molienda
# 22/06/2025 19:02:48 - GET: ReportePlaya
# 22/06/2025 19:02:49 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:07:51 - GET: Molienda
# 22/06/2025 19:07:51 - GET: ReportePlaya
# 22/06/2025 19:07:51 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:12:53 - GET: Molienda
# 22/06/2025 19:12:53 - GET: ReportePlaya
# 22/06/2025 19:12:53 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:17:55 - GET: Molienda
# 22/06/2025 19:17:55 - GET: ReportePlaya
# 22/06/2025 19:17:55 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:22:57 - GET: Molienda
# 22/06/2025 19:22:57 - GET: ReportePlaya
# 22/06/2025 19:22:58 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:28:00 - GET: Molienda
# 22/06/2025 19:28:00 - GET: ReportePlaya
# 22/06/2025 19:28:00 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:33:02 - GET: Molienda
# 22/06/2025 19:33:02 - GET: ReportePlaya
# 22/06/2025 19:33:02 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:38:04 - GET: Molienda
# 22/06/2025 19:38:04 - GET: ReportePlaya
# 22/06/2025 19:38:05 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:43:07 - GET: Molienda
# 22/06/2025 19:43:07 - GET: ReportePlaya
# 22/06/2025 19:43:07 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:48:09 - GET: Molienda
# 22/06/2025 19:48:09 - GET: ReportePlaya
# 22/06/2025 19:48:09 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:53:11 - GET: Molienda
# 22/06/2025 19:53:11 - GET: ReportePlaya
# 22/06/2025 19:53:11 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 19:58:13 - GET: Molienda
# 22/06/2025 19:58:13 - GET: ReportePlaya
# 22/06/2025 19:58:14 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:03:16 - GET: Molienda
# 22/06/2025 20:03:16 - GET: ReportePlaya
# 22/06/2025 20:03:16 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:08:18 - GET: Molienda
# 22/06/2025 20:08:18 - GET: ReportePlaya
# 22/06/2025 20:08:18 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:13:20 - GET: Molienda
# 22/06/2025 20:13:20 - GET: ReportePlaya
# 22/06/2025 20:13:21 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:18:23 - GET: Molienda
# 22/06/2025 20:18:23 - GET: ReportePlaya
# 22/06/2025 20:18:23 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:23:25 - GET: Molienda
# 22/06/2025 20:23:25 - GET: ReportePlaya
# 22/06/2025 20:23:25 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:28:27 - GET: Molienda
# 22/06/2025 20:28:27 - GET: ReportePlaya
# 22/06/2025 20:28:28 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:33:30 - GET: Molienda
# 22/06/2025 20:33:30 - GET: ReportePlaya
# 22/06/2025 20:33:30 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:38:32 - GET: Molienda
# 22/06/2025 20:38:32 - GET: ReportePlaya
# 22/06/2025 20:38:32 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:43:34 - GET: Molienda
# 22/06/2025 20:43:34 - GET: ReportePlaya
# 22/06/2025 20:43:35 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:48:37 - GET: Molienda
# 22/06/2025 20:48:37 - GET: ReportePlaya
# 22/06/2025 20:48:37 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:53:39 - GET: Molienda
# 22/06/2025 20:53:39 - GET: ReportePlaya
# 22/06/2025 20:53:39 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 20:58:41 - GET: Molienda
# 22/06/2025 20:58:41 - GET: ReportePlaya
# 22/06/2025 20:58:42 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:03:44 - GET: Molienda
# 22/06/2025 21:03:44 - GET: ReportePlaya
# 22/06/2025 21:03:44 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:08:46 - GET: Molienda
# 22/06/2025 21:08:46 - GET: ReportePlaya
# 22/06/2025 21:08:46 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:13:48 - GET: Molienda
# 22/06/2025 21:13:48 - GET: ReportePlaya
# 22/06/2025 21:13:49 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:18:51 - GET: Molienda
# 22/06/2025 21:18:51 - GET: ReportePlaya
# 22/06/2025 21:18:51 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:23:53 - GET: Molienda
# 22/06/2025 21:23:53 - GET: ReportePlaya
# 22/06/2025 21:23:53 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:28:55 - GET: Molienda
# 22/06/2025 21:28:55 - GET: ReportePlaya
# 22/06/2025 21:28:56 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:33:58 - GET: Molienda
# 22/06/2025 21:33:58 - GET: ReportePlaya
# 22/06/2025 21:33:58 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:39:00 - GET: Molienda
# 22/06/2025 21:39:00 - GET: ReportePlaya
# 22/06/2025 21:39:04 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:44:06 - GET: Molienda
# 22/06/2025 21:44:06 - GET: ReportePlaya
# 22/06/2025 21:44:06 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:49:08 - GET: Molienda
# 22/06/2025 21:49:08 - GET: ReportePlaya
# 22/06/2025 21:49:09 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:54:11 - GET: Molienda
# 22/06/2025 21:54:11 - GET: ReportePlaya
# 22/06/2025 21:54:11 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 21:59:13 - GET: Molienda
# 22/06/2025 21:59:13 - GET: ReportePlaya
# 22/06/2025 21:59:13 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:04:15 - GET: Molienda
# 22/06/2025 22:04:15 - GET: ReportePlaya
# 22/06/2025 22:04:16 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:09:18 - GET: Molienda
# 22/06/2025 22:09:18 - GET: ReportePlaya
# 22/06/2025 22:09:18 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:14:20 - GET: Molienda
# 22/06/2025 22:14:20 - GET: ReportePlaya
# 22/06/2025 22:14:20 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:19:22 - GET: Molienda
# 22/06/2025 22:19:23 - GET: ReportePlaya
# 22/06/2025 22:19:23 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:24:25 - GET: Molienda
# 22/06/2025 22:24:25 - GET: ReportePlaya
# 22/06/2025 22:24:25 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:29:27 - GET: Molienda
# 22/06/2025 22:29:27 - GET: ReportePlaya
# 22/06/2025 22:29:28 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:34:30 - GET: Molienda
# 22/06/2025 22:34:30 - GET: ReportePlaya
# 22/06/2025 22:34:30 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:39:32 - GET: Molienda
# 22/06/2025 22:39:32 - GET: ReportePlaya
# 22/06/2025 22:39:32 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:44:34 - GET: Molienda
# 22/06/2025 22:44:34 - GET: ReportePlaya
# 22/06/2025 22:44:35 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:49:37 - GET: Molienda
# 22/06/2025 22:49:37 - GET: ReportePlaya
# 22/06/2025 22:49:37 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:54:39 - GET: Molienda
# 22/06/2025 22:54:39 - GET: ReportePlaya
# 22/06/2025 22:54:40 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 22:59:42 - GET: Molienda
# 22/06/2025 22:59:42 - GET: ReportePlaya
# 22/06/2025 22:59:42 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:04:44 - GET: Molienda
# 22/06/2025 23:04:44 - GET: ReportePlaya
# 22/06/2025 23:04:44 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:09:46 - GET: Molienda
# 22/06/2025 23:09:46 - GET: ReportePlaya
# 22/06/2025 23:09:47 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:14:49 - GET: Molienda
# 22/06/2025 23:14:49 - GET: ReportePlaya
# 22/06/2025 23:14:49 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:19:51 - GET: Molienda
# 22/06/2025 23:19:51 - GET: ReportePlaya
# 22/06/2025 23:19:51 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:24:53 - GET: Molienda
# 22/06/2025 23:24:53 - GET: ReportePlaya
# 22/06/2025 23:24:54 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:29:56 - GET: Molienda
# 22/06/2025 23:29:56 - GET: ReportePlaya
# 22/06/2025 23:29:56 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:34:58 - GET: Molienda
# 22/06/2025 23:34:58 - GET: ReportePlaya
# 22/06/2025 23:34:59 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:40:01 - GET: Molienda
# 22/06/2025 23:40:01 - GET: ReportePlaya
# 22/06/2025 23:40:01 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:45:03 - GET: Molienda
# 22/06/2025 23:45:03 - GET: ReportePlaya
# 22/06/2025 23:45:03 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:50:05 - GET: Molienda
# 22/06/2025 23:50:05 - GET: ReportePlaya
# 22/06/2025 23:50:06 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 22/06/2025 23:55:08 - GET: Molienda
# 22/06/2025 23:55:08 - GET: ReportePlaya
# 22/06/2025 23:55:08 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:00:10 - GET: ReportePlaya
# 23/06/2025 00:00:10 - GET: Molienda
# 23/06/2025 00:00:10 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:05:12 - GET: ReportePlaya
# 23/06/2025 00:05:12 - GET: Molienda
# 23/06/2025 00:05:12 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:10:14 - GET: ReportePlaya
# 23/06/2025 00:10:14 - GET: Molienda
# 23/06/2025 00:10:14 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:15:16 - GET: ReportePlaya
# 23/06/2025 00:15:16 - GET: Molienda
# 23/06/2025 00:15:16 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:20:18 - GET: ReportePlaya
# 23/06/2025 00:20:18 - GET: Molienda
# 23/06/2025 00:20:18 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:25:20 - GET: ReportePlaya
# 23/06/2025 00:25:20 - GET: Molienda
# 23/06/2025 00:25:20 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:30:22 - GET: ReportePlaya
# 23/06/2025 00:30:22 - GET: Molienda
# 23/06/2025 00:30:22 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:35:24 - GET: ReportePlaya
# 23/06/2025 00:35:24 - GET: Molienda
# 23/06/2025 00:35:24 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:40:26 - GET: ReportePlaya
# 23/06/2025 00:40:26 - GET: Molienda
# 23/06/2025 00:40:26 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:45:28 - GET: ReportePlaya
# 23/06/2025 00:45:28 - GET: Molienda
# 23/06/2025 00:45:28 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:50:30 - GET: ReportePlaya
# 23/06/2025 00:50:30 - GET: Molienda
# 23/06/2025 00:50:30 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 00:55:32 - GET: ReportePlaya
# 23/06/2025 00:55:32 - GET: Molienda
# 23/06/2025 00:55:32 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:00:34 - GET: ReportePlaya
# 23/06/2025 01:00:34 - GET: Molienda
# 23/06/2025 01:00:34 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:05:36 - GET: ReportePlaya
# 23/06/2025 01:05:36 - GET: Molienda
# 23/06/2025 01:05:36 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:10:38 - GET: ReportePlaya
# 23/06/2025 01:10:38 - GET: Molienda
# 23/06/2025 01:10:38 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:15:40 - GET: ReportePlaya
# 23/06/2025 01:15:40 - GET: Molienda
# 23/06/2025 01:15:40 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:20:42 - GET: ReportePlaya
# 23/06/2025 01:20:42 - GET: Molienda
# 23/06/2025 01:20:42 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:25:44 - GET: ReportePlaya
# 23/06/2025 01:25:44 - GET: Molienda
# 23/06/2025 01:25:44 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:30:46 - GET: ReportePlaya
# 23/06/2025 01:30:46 - GET: Molienda
# 23/06/2025 01:30:47 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:35:49 - GET: ReportePlaya
# 23/06/2025 01:35:49 - GET: TrafCamBalanza
# 23/06/2025 01:35:52 - GET: Molienda
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:40:54 - GET: ReportePlaya
# 23/06/2025 01:40:54 - GET: Molienda
# 23/06/2025 01:40:54 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:45:56 - GET: ReportePlaya
# 23/06/2025 01:45:56 - GET: Molienda
# 23/06/2025 01:45:56 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:50:58 - GET: ReportePlaya
# 23/06/2025 01:50:58 - GET: Molienda
# 23/06/2025 01:50:59 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 01:56:00 - GET: ReportePlaya
# 23/06/2025 01:56:00 - GET: Molienda
# 23/06/2025 01:56:01 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:01:02 - GET: ReportePlaya
# 23/06/2025 02:01:02 - GET: Molienda
# 23/06/2025 02:01:02 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:06:04 - GET: ReportePlaya
# 23/06/2025 02:06:04 - GET: Molienda
# 23/06/2025 02:06:05 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:11:06 - GET: ReportePlaya
# 23/06/2025 02:11:07 - GET: Molienda
# 23/06/2025 02:11:07 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:16:09 - GET: ReportePlaya
# 23/06/2025 02:16:09 - GET: Molienda
# 23/06/2025 02:16:09 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:21:11 - GET: ReportePlaya
# 23/06/2025 02:21:11 - GET: Molienda
# 23/06/2025 02:21:11 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:26:13 - GET: ReportePlaya
# 23/06/2025 02:26:13 - GET: Molienda
# 23/06/2025 02:26:13 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:31:15 - GET: ReportePlaya
# 23/06/2025 02:31:15 - GET: Molienda
# 23/06/2025 02:31:15 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:36:17 - GET: ReportePlaya
# 23/06/2025 02:36:17 - GET: Molienda
# 23/06/2025 02:36:17 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:41:19 - GET: ReportePlaya
# 23/06/2025 02:41:19 - GET: Molienda
# 23/06/2025 02:41:19 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:46:21 - GET: ReportePlaya
# 23/06/2025 02:46:21 - GET: Molienda
# 23/06/2025 02:46:21 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:51:23 - GET: ReportePlaya
# 23/06/2025 02:51:23 - GET: Molienda
# 23/06/2025 02:51:23 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 02:56:25 - GET: ReportePlaya
# 23/06/2025 02:56:25 - GET: Molienda
# 23/06/2025 02:56:25 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:01:27 - GET: ReportePlaya
# 23/06/2025 03:01:27 - GET: Molienda
# 23/06/2025 03:01:27 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:06:29 - GET: ReportePlaya
# 23/06/2025 03:06:29 - GET: Molienda
# 23/06/2025 03:06:29 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:11:31 - GET: ReportePlaya
# 23/06/2025 03:11:31 - GET: Molienda
# 23/06/2025 03:11:31 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:16:33 - GET: ReportePlaya
# 23/06/2025 03:16:33 - GET: Molienda
# 23/06/2025 03:16:33 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:21:35 - GET: ReportePlaya
# 23/06/2025 03:21:35 - GET: Molienda
# 23/06/2025 03:21:35 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:26:37 - GET: ReportePlaya
# 23/06/2025 03:26:37 - GET: Molienda
# 23/06/2025 03:26:37 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:31:39 - GET: ReportePlaya
# 23/06/2025 03:31:39 - GET: Molienda
# 23/06/2025 03:31:39 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:36:41 - GET: ReportePlaya
# 23/06/2025 03:36:41 - GET: Molienda
# 23/06/2025 03:36:42 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:41:43 - GET: ReportePlaya
# 23/06/2025 03:41:44 - GET: Molienda
# 23/06/2025 03:41:44 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:46:46 - GET: ReportePlaya
# 23/06/2025 03:46:46 - GET: Molienda
# 23/06/2025 03:46:46 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:51:48 - GET: ReportePlaya
# 23/06/2025 03:51:48 - GET: Molienda
# 23/06/2025 03:51:48 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 03:56:50 - GET: ReportePlaya
# 23/06/2025 03:56:50 - GET: Molienda
# 23/06/2025 03:56:50 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:01:52 - GET: ReportePlaya
# 23/06/2025 04:01:52 - GET: TrafCamBalanza
# 23/06/2025 04:01:56 - GET: Molienda
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:06:58 - GET: ReportePlaya
# 23/06/2025 04:06:58 - GET: Molienda
# 23/06/2025 04:06:58 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:12:00 - GET: ReportePlaya
# 23/06/2025 04:12:00 - GET: Molienda
# 23/06/2025 04:12:00 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:17:02 - GET: ReportePlaya
# 23/06/2025 04:17:02 - GET: Molienda
# 23/06/2025 04:17:02 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:22:04 - GET: ReportePlaya
# 23/06/2025 04:22:04 - GET: Molienda
# 23/06/2025 04:22:04 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:27:06 - GET: ReportePlaya
# 23/06/2025 04:27:06 - GET: Molienda
# 23/06/2025 04:27:06 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:32:08 - GET: ReportePlaya
# 23/06/2025 04:32:08 - GET: TrafCamBalanza
# 23/06/2025 04:32:12 - GET: Molienda
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:37:14 - GET: ReportePlaya
# 23/06/2025 04:37:14 - GET: Molienda
# 23/06/2025 04:37:14 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:42:16 - GET: ReportePlaya
# 23/06/2025 04:42:16 - GET: Molienda
# 23/06/2025 04:42:16 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:47:18 - GET: ReportePlaya
# 23/06/2025 04:47:18 - GET: Molienda
# 23/06/2025 04:47:18 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:52:20 - GET: ReportePlaya
# 23/06/2025 04:52:20 - GET: Molienda
# 23/06/2025 04:52:20 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 04:57:22 - GET: ReportePlaya
# 23/06/2025 04:57:22 - GET: Molienda
# 23/06/2025 04:57:22 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:02:24 - GET: ReportePlaya
# 23/06/2025 05:02:24 - GET: Molienda
# 23/06/2025 05:02:24 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:07:26 - GET: ReportePlaya
# 23/06/2025 05:07:27 - GET: Molienda
# 23/06/2025 05:07:27 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:12:28 - GET: ReportePlaya
# 23/06/2025 05:12:29 - GET: Molienda
# 23/06/2025 05:12:29 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:17:31 - GET: ReportePlaya
# 23/06/2025 05:17:31 - GET: Molienda
# 23/06/2025 05:17:31 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:22:33 - GET: ReportePlaya
# 23/06/2025 05:22:33 - GET: Molienda
# 23/06/2025 05:22:33 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:27:35 - GET: ReportePlaya
# 23/06/2025 05:27:35 - GET: Molienda
# 23/06/2025 05:27:35 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:32:37 - GET: ReportePlaya
# 23/06/2025 05:32:37 - GET: Molienda
# 23/06/2025 05:32:37 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:37:39 - GET: ReportePlaya
# 23/06/2025 05:37:39 - GET: Molienda
# 23/06/2025 05:37:39 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:42:41 - GET: ReportePlaya
# 23/06/2025 05:42:41 - GET: Molienda
# 23/06/2025 05:42:41 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:47:43 - GET: ReportePlaya
# 23/06/2025 05:47:43 - GET: Molienda
# 23/06/2025 05:47:43 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:52:45 - GET: ReportePlaya
# 23/06/2025 05:52:45 - GET: Molienda
# 23/06/2025 05:52:45 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 05:57:47 - GET: ReportePlaya
# 23/06/2025 05:57:47 - GET: Molienda
# 23/06/2025 05:57:48 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:02:49 - GET: ReportePlaya
# 23/06/2025 06:02:50 - GET: TrafCamBalanza
# 23/06/2025 06:02:53 - GET: Molienda
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:07:55 - GET: ReportePlaya
# 23/06/2025 06:07:55 - GET: Molienda
# 23/06/2025 06:07:55 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:12:57 - GET: ReportePlaya
# 23/06/2025 06:12:57 - GET: Molienda
# 23/06/2025 06:12:58 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:17:59 - GET: ReportePlaya
# 23/06/2025 06:18:00 - GET: Molienda
# 23/06/2025 06:18:00 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:23:02 - GET: ReportePlaya
# 23/06/2025 06:23:02 - GET: Molienda
# 23/06/2025 06:23:02 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:28:04 - GET: ReportePlaya
# 23/06/2025 06:28:04 - GET: Molienda
# 23/06/2025 06:28:04 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:33:06 - GET: ReportePlaya
# 23/06/2025 06:33:06 - GET: Molienda
# 23/06/2025 06:33:06 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:38:08 - GET: ReportePlaya
# 23/06/2025 06:38:08 - GET: Molienda
# 23/06/2025 06:38:08 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:43:10 - GET: ReportePlaya
# 23/06/2025 06:43:10 - GET: Molienda
# 23/06/2025 06:43:10 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:48:12 - GET: ReportePlaya
# 23/06/2025 06:48:12 - GET: Molienda
# 23/06/2025 06:48:12 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:53:14 - GET: ReportePlaya
# 23/06/2025 06:53:14 - GET: Molienda
# 23/06/2025 06:53:14 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 06:58:16 - GET: ReportePlaya
# 23/06/2025 06:58:16 - GET: Molienda
# 23/06/2025 06:58:16 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:03:18 - GET: Molienda
# 23/06/2025 07:03:18 - GET: ReportePlaya
# 23/06/2025 07:03:19 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:08:21 - GET: Molienda
# 23/06/2025 07:08:21 - GET: ReportePlaya
# 23/06/2025 07:08:21 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:13:23 - GET: Molienda
# 23/06/2025 07:13:23 - GET: ReportePlaya
# 23/06/2025 07:13:23 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:18:25 - GET: Molienda
# 23/06/2025 07:18:25 - GET: ReportePlaya
# 23/06/2025 07:18:25 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:23:27 - GET: Molienda
# 23/06/2025 07:23:27 - GET: ReportePlaya
# 23/06/2025 07:23:27 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:28:29 - GET: Molienda
# 23/06/2025 07:28:29 - GET: ReportePlaya
# 23/06/2025 07:28:29 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:33:31 - GET: Molienda
# 23/06/2025 07:33:31 - GET: ReportePlaya
# 23/06/2025 07:33:31 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:38:33 - GET: Molienda
# 23/06/2025 07:38:34 - GET: ReportePlaya
# 23/06/2025 07:38:34 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:43:36 - GET: Molienda
# 23/06/2025 07:43:36 - GET: ReportePlaya
# 23/06/2025 07:43:36 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:48:38 - GET: ReportePlaya
# 23/06/2025 07:48:38 - GET: Molienda
# 23/06/2025 07:48:38 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:53:40 - GET: Molienda
# 23/06/2025 07:53:40 - GET: ReportePlaya
# 23/06/2025 07:53:40 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 07:58:42 - GET: Molienda
# 23/06/2025 07:58:42 - GET: ReportePlaya
# 23/06/2025 07:58:42 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 08:03:44 - GET: Molienda
# 23/06/2025 08:03:44 - GET: ReportePlaya
# 23/06/2025 08:03:45 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 08:08:47 - GET: ReportePlaya
# 23/06/2025 08:08:47 - GET: Molienda
# 23/06/2025 08:08:47 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 08:13:49 - GET: Molienda
# 23/06/2025 08:13:49 - GET: ReportePlaya
# 23/06/2025 08:13:49 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 08:18:51 - GET: Molienda
# 23/06/2025 08:18:51 - GET: ReportePlaya
# 23/06/2025 08:18:51 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 08:23:53 - GET: Molienda
# 23/06/2025 08:23:53 - GET: ReportePlaya
# 23/06/2025 08:23:53 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 08:28:55 - GET: Molienda
# 23/06/2025 08:28:55 - GET: ReportePlaya
# 23/06/2025 08:28:55 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 08:33:57 - GET: Molienda
# 23/06/2025 08:33:57 - GET: ReportePlaya
# 23/06/2025 08:33:58 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# 23/06/2025 08:38:59 - GET: Molienda
# 23/06/2025 08:39:00 - GET: ReportePlaya
# 23/06/2025 08:39:00 - GET: TrafCamBalanza
# ✅ Registro actualizado correctamente (SQLAlchemy)
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[68], line 3
#       1 # 5️⃣ Ejecutar
#       2 if __name__ == "__main__":
# ----> 3     await ciclo_principal()
#
# Cell In[67], line 31, in ciclo_principal()
#      29 else:
#      30     print("⚠️ No se pudieron obtener todos los datos. Se omite el cálculo.")
# ---> 31 await asyncio.sleep(300)
#
# File ~\anaconda3\envs\utea\lib\asyncio\tasks.py:605, in sleep(delay, result)
#     601 h = loop.call_later(delay,
#     602                     futures._set_result_unless_cancelled,
#     603                     future, result)
#     604 try:
# --> 605     return await future
#     606 finally:
#     607     h.cancel()
#
# CancelledError:
