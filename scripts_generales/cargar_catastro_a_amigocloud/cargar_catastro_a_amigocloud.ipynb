# %%
import geopandas as gpd
import matplotlib.pyplot as mpl
import fiona

# %%
fp = r'D:\BISMARK_SOCOMPI\TEST\ROCIO.shp'
catastro = gpd.read_file(fp)

# %%
columnas_nuevas = {'unidad_01':'cod_prop', 
                   'unidad_02':'nom_prop', 
                   'unidad_03':'cod_ca', 
                   'unidad_04':'nom_ca', 
                   'unidad_05':'lote', 
                   'variedad':'variedad', 
                   'fs':'fs', 
                   'textura':'textura', 
                   'financiami':'financiamiento', 
                   'gestion':'gestion', 
                   'soca':'soca', 
                   'cultivo':'cultivo', 
                   'ins':'inst', 
                   'area':'area'}

# %%
catastro.plot()
mpl.show()

# %%
catastro.head(3)
# Out:
#    unidad_01 unidad_05            id          id_1  unidad_012  \
# 0         30        L1  0000300000L1  0000300000L1          30
# 1         30        L7  0000300000L7  0000300000L7          30
# 2         30        L8  0000300000L8  0000300000L8          30
#
#              unidad_02  unidad_03                        unidad_04 unidad_056  \
# 0  EL PAILON I.A.G S.A      41594  AGROPECUARIA CAMPO DULCE S.R.L.         L1
# 1  EL PAILON I.A.G S.A      41594  AGROPECUARIA CAMPO DULCE S.R.L.         L7
# 2  EL PAILON I.A.G S.A      41594  AGROPECUARIA CAMPO DULCE S.R.L.         L8
#
#     variedad          fs textura financiami  gestion  soca cultivo  ins  \
# 0       RB-2  2021-05-08      FA        IAG     2021     1   canha   50
# 1  RBB 77-26  2022-03-15       F       None     2022     0   canha   50
# 2       RB-2  2021-05-09      FY        IAG     2021     1   canha   50
#
#   responsabl       area                                           geometry
# ...

# %%
catastro.rename(columns=columnas_nuevas, inplace=True)

# %%
catastro.head(3)
# Out:
#    cod_prop lote            id          id_1  unidad_012             nom_prop  \
# 0        30   L1  0000300000L1  0000300000L1          30  EL PAILON I.A.G S.A
# 1        30   L7  0000300000L7  0000300000L7          30  EL PAILON I.A.G S.A
# 2        30   L8  0000300000L8  0000300000L8          30  EL PAILON I.A.G S.A
#
#    cod_ca                           nom_ca unidad_056   variedad          fs  \
# 0   41594  AGROPECUARIA CAMPO DULCE S.R.L.         L1       RB-2  2021-05-08
# 1   41594  AGROPECUARIA CAMPO DULCE S.R.L.         L7  RBB 77-26  2022-03-15
# 2   41594  AGROPECUARIA CAMPO DULCE S.R.L.         L8       RB-2  2021-05-09
#
#   textura financiamiento  gestion  soca cultivo  inst responsabl       area  \
# 0      FA            IAG     2021     1   canha    50       None  11.563787
# 1       F           None     2022     0   canha    50       None  15.371285
# 2      FY            IAG     2021     1   canha    50       None  27.445201
#
# ...
