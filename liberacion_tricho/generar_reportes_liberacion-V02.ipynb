# %%
import qrcode

from docxtpl import DocxTemplate
import docxtpl
from docx.shared import Mm
import matplotlib.patches as mpatches
import requests

from matplotlib.lines import Line2D

# %%
import math
import contextily as ctx

import rasterio
from rasterio.plot import show

import collections

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime

from descartes import PolygonPatch

# %%
# ruta de carpera donde estan las llaves
ruta = open('../ruta.txt')
ruta = ruta.readlines()[0]
ruta
# Out:
# 'G:\\OneDrive - Ingenio Azucarero Guabira S.A\\_DATOS_PYTHON'

# %%
path_shp = r'G:\Ingenio Azucarero Guabira S.A\CITTCA - SEMANAL - Documents\SHP_SEGUIMIENTO\SHP_SEGUIMIENTO.shp'
path_shp_cat = r'G:\OneDrive - Ingenio Azucarero Guabira S.A\INFORMACION GENERAL\CATASTRO\NUEVO\catastro150324.shp'

# %%
path_xlsx = r'G:\Ingenio Azucarero Guabira S.A\CITTCA - SEMANAL - Documents\test_4.xlsx'

# %%
df = pd.read_excel(path_xlsx)
df.head(3)
# Out:
#   Nº DE LABOR      FECHA  SEMANA  INSTITUCIÓN  COD CAÑERO  \
# 0         A-1 2023-09-05      36           50       14562
# 1         A-1 2023-09-05      36           50       14562
# 2         A-1 2023-09-05      36           50       14562
#
#                 NOMBRE CAÑERO  COD PROPIEDAD           NOMBRE DE PROPIEDAD  \
# 0  VACA HURTADO JULIO ERNESTO            184  EL CARMEN CIDRAL--JULIO VACA
# 1  VACA HURTADO JULIO ERNESTO            184  EL CARMEN CIDRAL--JULIO VACA
# 2  VACA HURTADO JULIO ERNESTO            184  EL CARMEN CIDRAL--JULIO VACA
#
#               LABOR_REALIZADA HORA DE INICIO  ... OPERACIÓN DETENIDA POR:  \
# 0  LIBERACION DE TRICHOGRAMMA       00:00:00  ...    OPERACIÓN FINALIZADA
# 1  LIBERACION DE TRICHOGRAMMA       00:00:00  ...    OPERACIÓN FINALIZADA
# 2  LIBERACION DE TRICHOGRAMMA       00:00:00  ...    OPERACIÓN FINALIZADA
#
#    COD DRONE  PILOTO  NRO. LIBERACION    OBSERVACIONES  \
# 0        NaN     NaN              1.0  SIN OBSERVACION
# 1        NaN     NaN              1.0  SIN OBSERVACION
# 2        NaN     NaN              1.0  SIN OBSERVACION
#
#    CONFORMIDAD DEL CAÑERO/SUPERVISOR ORIGEN           IDD REPORTE Columna1
# 0                                NaN  EXCEL  184-14562-36     NaN        A
# 1                                NaN  EXCEL  184-14562-36     NaN        A
# 2                                NaN  EXCEL  184-14562-36     NaN        A
#
# [3 rows x 28 columns]

# %%
lista_cod = list(set(df['IDD']))

# %%
print(len(lista_cod))
# Out:
# 656

# %%
print(lista_cod)
# Out:
# ['5-1858-5', '705-18028-6', '5-1858-49', '29-594-39', '1594-10650-51', '33-633-41', '831-41834-52', '98-2662-2', '435-2876-5', '201-2505-6', '1358-3361-2', '1703-1686-5', '1015-40256-3', '220-2641-38', '1776-2876-49', '759-5385-2', '1646-2565-2', '43-11750-1', '140-42033-52', '1926-1533-3', '1696-42163-49', '1776-2876-3', '469-5401-5', '1772-2876-4', '1469-402-4', '327-7506-5', '1294-8017-5', '1587-2285-3', '519-10650-51', '1761-41529-50', '1719-13132-7', '114-11860-37', '297-2007-5', '1716-402-6', '1301-2876-49', '1960-1068-51', '100-3421-3', '1709-4914-7', '74-2816-47', '1114-30895-49', '1726-767-6', '1704-721-1', '375-18027-4', '1294-8017-48', '31-633-4', '1454-41534-37', '98-3421-2', '17-515-1', '33-633-39', '758-4146-50', '1891-2446-8', '545-5448-51', '872-8523-2', '159-40130-5', '1816-1180-43', '519-10650-45', '1911-12190-47', '307-30035-4', '98-3421-5', '55-86-45', '238-10494-44', '1702-12075-48', '398-20048-51', '297-1979-2', '299-1530-2', '329-2880-51', '33-633-5', '1592-2517-50', '910-5307-43', '29-594-49', '1770-17680-2', '1180-9687-50', '1618-12308-7', '12-18125-49', '30-41594-39', '783-17678-50', '142-15162-52', '217-75-42', '1718-11957-6', '636-42239-4', '558-4834-42', '1965-2626-4', '237-10494-44', '1-388-47', '98-2662-49', '104-1533-3', '84-1741-4', '174-743-43', '715-167-6', '55-86-48', '705-40144-3', '1765-20048-51', '1929-1533-6', '1709-709-50', '300-2899-36', '1489-1533-3', '13-86-48', '1716-402-50', '566-5423-48', '458-41819-51', '126-42165-45', '758-41529-50', '941-7494-5', '435-2876-3', '297-2007-2', '48-18100-50', '1817-1171-43', '904-2557-50', '1574-4537-50', '729-13026-3', '1539-41967-6', '201-15085-6', '604-6626-50', '1039-20180-52', '1580-15195-6', '36-10816-47', '279-12478-41', '419-2510-4', '285-8829-5', '421-5307-5', '201-2510-6', '666-2719-4', '1826-41823-52', '43-11617-5', '297-2007-50', '358-1533-52', '628-2285-50', '416-2274-51', '400-446-45', '1716-402-3', '468-5332-48', '222-8838-49', '5-1858-3', '327-7506-4', '239-9677-7', '1702-12075-52', '1704-721-52', '767-5006-50', '62-446-45', '30-41594-2', '1-18358-47', '872-8523-50', '625-692-48', '375-18027-6', '673-2315-36', '31-633-1', '1374-924-4', '830-1533-52', '1702-11576-48', '555-751-5', '187-5421-3', '1475-13652-51', '1765-20048-4', '184-14562-40', '605-6626-4', '1790-11588-4', '1817-1171-50', '222-8814-49', '773-5006-50', '85-12162-47', '1726-767-50', '253-40256-3', '1592-2517-4', '30-41594-43', '324-4839-47', '279-12478-43', '1294-8017-51', '1580-15195-4', '1819-18191-50', '1214-1741-50', '559-4844-4', '830-1533-48', '30-41594-37', '22-6638-6', '1777-8823-48', '1702-11576-52', '122-15501-38', '201-2220-51', '1349-7385-52', '1043-20180-5', '54-8624-44', '1786-2650-49', '1414-40270-6', '1911-12190-45', '367-42239-6', '1694-18189-50', '1520-2641-5', '666-2719-5', '104-1533-6', '1131-1533-6', '1342-18028-5', '1579-41827-6', '1653-41544-52', '43-11617-1', '1198-18028-6', '1967-42148-38', '773-5006-4', '1852-15001-42', '33-633-1', '184-14562-42', '1374-924-50', '594-7519-49', '941-7494-52', '779-42164-3', '277-2029-41', '329-2880-4', '395-5498-52', '89-8684-4', '197-1741-50', '1120-3382-5', '1040-20180-51', '1545-3378-49', '184-14562-36', '62-630-49', '415-2510-4', '1040-20180-5', '1893-42178-5', '1114-30895-5', '636-42239-5', '279-12478-38', '242-692-1', '1790-11588-51', '85-12162-4', '328-86-40', '30-41594-48', '18-18088-44', '1464-2517-50', '329-2883-51', '1198-18028-4', '949-8014-5', '809-42047-48', '729-12998-3', '1038-13062-51', '1967-42148-42', '758-4146-2', '519-10650-42', '62-47-45', '1786-2650-2', '1865-42178-5', '1401-770-5', '31-633-39', '98-2662-5', '855-12118-2', '796-41550-47', '1926-1533-6', '236-10494-44', '300-2899-39', '40-40252-52', '1342-18028-49', '222-8814-3', '468-5332-52', '330-2880-4', '216-75-45', '928-12998-4', '519-10650-5', '907-5307-52', '230-4537-6', '265-41966-50', '256-75-45', '1301-2876-5', '1587-2285-50', '1686-40130-4', '222-8838-6', '949-8014-44', '1761-41529-6', '1454-41534-41', '29-594-41', '445-12505-3' ...

# %%
lista_cod = ['1144|3420|50', '519|10650|5', '1701|2626|5', '89|8684|4', '122|15501|41', '1039|20180|52', '19|388|51', '791|20262|45', '55|86|47', '1040|20180|5', '187|5421|3', '5|1858|5', '1038|13062|51', '222|8814|6', '33|633|1', '114|11860|37']
print(lista_cod)
# Out:
# ['1144|3420|50', '519|10650|5', '1701|2626|5', '89|8684|4', '122|15501|41', '1039|20180|52', '19|388|51', '791|20262|45', '55|86|47', '1040|20180|5', '187|5421|3', '5|1858|5', '1038|13062|51', '222|8814|6', '33|633|1', '114|11860|37']

# %%
#RUTA DE RECORRIDO
lineas = r'C:\Test\AGUAS_NEGRAS_14-02.shp'

# %%
for k in lista_cod:
    lista = k.split('-')
    cod_prop = lista[0]
    cod_ca = lista[1]
    semana = lista[2]
    
    print('INICIA ID: ', k)
    #x = df[df['COD_ID']==k]
    #cod_prop = int(x['COD PROPIEDAD'].iloc[0])
    #semana = int(x['SEMANA'].iloc[0])
    
    #registro = df[df['IDD']==k]

    registro = df[(df['COD PROPIEDAD'] == int(cod_prop)) & (df['COD CAÑERO'] == int(cod_ca)) & (df['SEMANA'] == int(semana))]
    
    registro['FECHA'] = registro['FECHA'].astype(str)
    
    data_rep = {
        'id' : registro['IDD'].iloc[0],
        'nro_reg': '000' + str(registro['Nº DE LABOR'].iloc[0]), 
        'fecha' : registro['FECHA'].iloc[0],
        'nom_ca' : registro['NOMBRE CAÑERO'].iloc[0],
        'cod_ca' : registro['COD CAÑERO'].iloc[0],
        'nom_prop' : registro['NOMBRE DE PROPIEDAD'].iloc[0],
        'cod_prop' : registro['COD PROPIEDAD'].iloc[0],
        'inst' : int(registro['INSTITUCIÓN'].iloc[0]),
        'total': registro['HECTÁREAS'].sum(),
        
        'temp' : registro['TEMPERATURA °C'].iloc[0],
        'viento' : registro['VIENTO'].iloc[0],
        'humedad' : registro['HUMEDAD'].iloc[0],
        'cod_dron' : registro['COD DRONE'].iloc[0],
        'piloto' : registro['PILOTO'].iloc[0]
    }
    
    data_rep2 = collections.namedtuple("data", data_rep.keys())(*data_rep.values())
    
    shp_apli = gpd.read_file(path_shp)
    cat = gpd.read_file(path_shp_cat)
    #line = gpd.read_file(lineas)
    
    apli = shp_apli[(shp_apli['unidad_01'] == int(cod_prop)) & (shp_apli['unidad_03'] == int(cod_ca)) & (shp_apli['semana'] == int(semana))]
    prop = cat[cat['unidad_01'] == int(cod_prop)]
    total_area = apli['area'].sum()
    total_ha = registro['HECTÁREAS'].sum()
    diff = total_ha - total_area
    
    if diff > 0:
        cantidad = len(apli)
        incre = diff / cantidad
        apli['area'] = apli['area'] + incre
    else:
        diff = diff * (-1)
        cantidad = len(apli)
        incre = diff / cantidad
        apli['area'] = apli['area'] - incre
    
    lotes = []
    for i, r in apli.iterrows():
        lote = {
            'nombre' : r['unidad_05'],
            'area' : round(r['area'], 2)
        }
        collec = collections.namedtuple("lote", lote.keys())(*lote.values())
        lotes.append(collec)

        
    filename_img = str(data_rep['cod_ca']) + '_' + str(data_rep['cod_prop']) + '_' + data_rep['fecha']
    
    apli = apli.to_crs(epsg=3857)
    prop = prop.to_crs(epsg=3857)
    #line = line.to_crs(epsg=3857)
    # Asegúrate de que 'gdf' es tu GeoDataFrame que ya tiene una columna 'geometry' con polígonos
    # Crea una figura y un eje con Matplotlib
    fig, ax = plt.subplots(figsize=(12, 8))
    
    prop.plot(ax=ax, edgecolor='blue', facecolor='none', linewidth=1)
    # Grafica los polígonos utilizando la función plot de Geopandas
    # 'edgecolor' es el color del borde, 'facecolor' es el color de relleno
    apli.plot(ax=ax, edgecolor='yellow', facecolor='none', linewidth=2)
    
    #line.plot(ax=ax, color='red', linestyle='--', linewidth=1)
    
    for idx, row in apli.iterrows():
        # Representa el punto central del polígono
        centroid = row.geometry.centroid
        # Anota el 'id' en el centro
        ax.annotate(
            text=row['unidad_05'] + ' \n' + str(round(row['area'], 2)) + 'ha', 
            xy=(centroid.x, centroid.y), 
            ha='center', 
            va='center', 
            weight=1000,
            fontsize=6,
            bbox=dict(facecolor=(1,1,1,0.3), edgecolor='none', pad=0))


    # Agregar la imagen de satélite como mapa base con Contextily
    ctx.add_basemap(ax, source=ctx.providers.Esri.WorldImagery)
    
    # Ajustar los límites del eje al área de los polígonos
    #ax.set_xlim(apli.total_bounds[[0, 2]])
    #ax.set_ylim(apli.total_bounds[[1, 3]])
    
    minx, miny, maxx, maxy = prop.total_bounds
    ax.set_xlim(minx - 500, maxx + 500)
    ax.set_ylim(miny - 400, maxy + 400)
    
    handle1 = Line2D([0], [0], color='blue', linewidth=1, linestyle='-', label='Lotes de propiedad')
    #handle2 = mpatches.Patch(color='yellow', label='Lotes con liberacion')
    handle2 = Line2D([0], [0], color='yellow', linewidth=1, linestyle='-', label='Lotes con liberacion')
    # Crear un handle para las líneas, asumiendo que representan canales de irrigación o caminos
    #handle3 = Line2D([0], [0], color='red', linewidth=1, linestyle='--', label='Recorrido Dron')
    
    
    # Añade la leyenda con los handles creados
    ax.legend(handles=[handle1, handle2])
    
    # Omitir los ejes para una visualización más limpia
    ax.axis('off')
    
    # Muestra el gráfico
    ruta_plano = ruta + '/planos/' + filename_img + '.jpeg'
    fig.savefig(ruta_plano, dpi = 300, bbox_inches='tight')
    plt.show()
    plt.clf()
    
    
    
    
    
    # Datos que quieres que contenga el QR
    texto = '''
    --UTEA--
    --LIBERACION DE TRICHOGRAMMA--

    Numero de Liberacion: {nro_reg}
    Fecha de Liberacion: {fecha}
    Nombre de Canero: {canero}
    Codigo Canero: {cod_ca}
    Propiedad: {prop}
    Total Area Liberada: {area} ha'''\
    .format(
        nro_reg=data_rep['nro_reg'], 
        fecha=data_rep['fecha'], 
        canero=data_rep['nom_ca'],
        cod_ca=data_rep['cod_ca'],
        prop=data_rep['nom_prop'],
        area=data_rep['total'])
    # Generar el código QR
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=10,
        border=4,
    )
    qr.add_data(texto)
    qr.make(fit=True)
    
    img = qr.make_image(fill_color="black", back_color="white")
    
    filename_qr = 'qr_' + str(data_rep['cod_ca']) + '_' + str(data_rep['cod_prop']) + '_' + data_rep['fecha']
    ruta_qr = ruta + '/planos/' + filename_qr + '.png'
    # Guardar el código QR en un archivo
    img.save(ruta_qr)
    
    doc = DocxTemplate(ruta + "/templates/tpl_rpt_liberacion_tricho.docx")
    in_line_plano = docxtpl.InlineImage(doc, image_descriptor=ruta_plano, width=Mm(170))
    in_line_qr = docxtpl.InlineImage(doc, image_descriptor=ruta_qr, width=Mm(30))
    context = {'data':data_rep2, 'lotes':lotes, 'plano':in_line_plano, 'qr':in_line_qr}
    doc.render(context)
    filename = str(data_rep['id']) + '_' + str(data_rep['cod_ca']) + '_' + data_rep['nom_ca'] + '_' + '_' + data_rep['fecha']
    doc.save(ruta + '/informes/' + filename + '.docx')
# Out:
#   Cell In[1], line 2
#     lista = k.split('-')
#     ^
# IndentationError: unexpected indent

# %%
lista_cod
# Out:
# ['30|41594|45',
#  '333|6550|45',
#  '1816|1180|45',
#  '674|41973|45',
#  '216|75|45',
#  '63|2641|44',
#  '126|42165|45',
#  '519|10650|45',
#  '265|41966|45',
#  '256|75|45',
#  '791|20262|45',
#  '55|86|45',
#  '1911|12190|45',
#  '299|1530|45',
#  '1817|1171|45',
#  '50|5373|44',
#  '220|2641|44',
#  '13|86|45']

# %%
lista = lista_cod[1].split('|')

# %%
cod_prop = lista[0]
cod_ca = lista[1]
semana = lista[2]

# %%
registro = df[df['IDD']==lista_cod[1]]
registro
# Out:
#     Nº DE LABOR      FECHA  SEMANA  INSTITUCIÓN  COD CAÑERO  \
# 246        B-31 2023-11-09      45           69        6550
# 247        B-31 2023-11-09      45           69        6550
# 248        B-31 2023-11-09      45           69        6550
# 249        B-31 2023-11-09      45           69        6550
# 250        B-31 2023-11-09      45           69        6550
# 251        B-31 2023-11-09      45           69        6550
#
#                  NOMBRE CAÑERO  COD PROPIEDAD  NOMBRE DE PROPIEDAD  \
# 246  JUSTINIANO PEREYRA ALVARO            333  LA CUTA--JUSTINIANO
# 247  JUSTINIANO PEREYRA ALVARO            333  LA CUTA--JUSTINIANO
# 248  JUSTINIANO PEREYRA ALVARO            333  LA CUTA--JUSTINIANO
# 249  JUSTINIANO PEREYRA ALVARO            333  LA CUTA--JUSTINIANO
# 250  JUSTINIANO PEREYRA ALVARO            333  LA CUTA--JUSTINIANO
# 251  JUSTINIANO PEREYRA ALVARO            333  LA CUTA--JUSTINIANO
#
#                 LABOR_REALIZADA HORA DE INICIO  ... DOSIS  \
# 246  LIBERACION DE TRICHOGRAMMA       22:43:00  ...   0.6
# 247  LIBERACION DE TRICHOGRAMMA       22:43:00  ...   0.6
# 248  LIBERACION DE TRICHOGRAMMA       22:43:00  ...   0.6
# 249  LIBERACION DE TRICHOGRAMMA       22:43:00  ...   0.6
# 250  LIBERACION DE TRICHOGRAMMA       22:43:00  ...   0.6
# 251  LIBERACION DE TRICHOGRAMMA       22:43:00  ...   0.6
#
#      OPERACIÓN DETENIDA POR:  COD DRONE        PILOTO NRO. LIBERACION  \
# 246    VELOCIDAD DEL VIENTO   PHANTON 4  JOSUE CANEDO             NaN
# 247    VELOCIDAD DEL VIENTO   PHANTON 4  JOSUE CANEDO             NaN
# 248    VELOCIDAD DEL VIENTO   PHANTON 4  JOSUE CANEDO             NaN
# 249    VELOCIDAD DEL VIENTO   PHANTON 4  JOSUE CANEDO             NaN
# 250    VELOCIDAD DEL VIENTO   PHANTON 4  JOSUE CANEDO             NaN
# 251    VELOCIDAD DEL VIENTO   PHANTON 4  JOSUE CANEDO             NaN
#
#                                          OBSERVACIONES  \
# 246  NO SE LIBERO LOS LOTES C6; D7; D6,1; D3, POR M...
# 247  NO SE LIBERO LOS LOTES C6; D7; D6,1; D3, POR M...
# 248  NO SE LIBERO LOS LOTES C6; D7; D6,1; D3, POR M...
# 249  NO SE LIBERO LOS LOTES C6; D7; D6,1; D3, POR M...
# 250  NO SE LIBERO LOS LOTES C6; D7; D6,1; D3, POR M...
# 251  NO SE LIBERO LOS LOTES C6; D7; D6,1; D3, POR M...
#
#     CONFORMIDAD DEL CAÑERO/SUPERVISOR  ORIGEN          IDD REPORTE
# 246                      JHONNY COSIO     NaN  333|6550|45     NaN
# 247                      JHONNY COSIO     NaN  333|6550|45     NaN
# 248                      JHONNY COSIO     NaN  333|6550|45     NaN
# 249                      JHONNY COSIO     NaN  333|6550|45     NaN
# 250                      JHONNY COSIO     NaN  333|6550|45     NaN
# 251                      JHONNY COSIO     NaN  333|6550|45     NaN
#
# [6 rows x 27 columns]

# %%
registro['FECHA'] = registro['FECHA'].astype(str)
# Out:
# C:\Users\Usuario\anaconda3\envs\utea_reportes\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
registro.columns
# Out:
# Index(['Nº DE LABOR', 'FECHA', 'SEMANA', 'INSTITUCIÓN', 'COD CAÑERO',
#        'NOMBRE CAÑERO', 'COD PROPIEDAD', 'NOMBRE DE PROPIEDAD',
#        'LABOR_REALIZADA', 'HORA DE INICIO', 'HORA FINAL', 'TEMPERATURA °C',
#        'VIENTO', 'HUMEDAD', 'LOTE', 'HECTÁREAS', 'PRODUCTO', 'DOSIS',
#        'OPERACIÓN DETENIDA POR:', 'COD DRONE', 'PILOTO', 'NRO. LIBERACION',
#        'OBSERVACIONES', 'CONFORMIDAD DEL CAÑERO/SUPERVISOR', 'ORIGEN', 'IDD',
#        'REPORTE'],
#       dtype='object')

# %%
data_rep = {
    'nro_reg': '000' + str(registro['Nº DE LABOR'].iloc[0]), 
    'fecha' : registro['FECHA'].iloc[0],
    'nom_ca' : registro['NOMBRE CAÑERO'].iloc[0],
    'cod_ca' : registro['COD CAÑERO'].iloc[0],
    'nom_prop' : registro['NOMBRE DE PROPIEDAD'].iloc[0],
    'cod_prop' : registro['COD PROPIEDAD'].iloc[0],
    'inst' : int(registro['INSTITUCIÓN'].iloc[0]),
    'total': registro['HECTÁREAS'].sum(),
    
    'temp' : registro['TEMPERATURA °C'].iloc[0],
    'viento' : registro['VIENTO'].iloc[0],
    'humedad' : registro['HUMEDAD'].iloc[0],
    'cod_dron' : registro['COD DRONE'].iloc[0],
    'piloto' : registro['PILOTO'].iloc[0]
}
data_rep
# Out:
# {'nro_reg': '000B-31',
#  'fecha': '2023-11-09',
#  'nom_ca': 'JUSTINIANO PEREYRA ALVARO',
#  'cod_ca': 6550,
#  'nom_prop': 'LA CUTA--JUSTINIANO',
#  'cod_prop': 333,
#  'inst': 69,
#  'total': 29.0,
#  'temp': 30,
#  'viento': 0,
#  'humedad': 69,
#  'cod_dron': 'PHANTON 4',
#  'piloto': 'JOSUE CANEDO'}

# %%
data_rep2 = collections.namedtuple("data", data_rep.keys())(*data_rep.values())
data_rep2
# Out:
# data(nro_reg='000B-31', fecha='2023-11-09', nom_ca='JUSTINIANO PEREYRA ALVARO', cod_ca=6550, nom_prop='LA CUTA--JUSTINIANO', cod_prop=333, inst=69, total=29.0, temp=30, viento=0, humedad=69, cod_dron='PHANTON 4', piloto='JOSUE CANEDO')

# %%
shp_apli = gpd.read_file(path_shp)

# %%
cat = gpd.read_file(path_shp_cat)

# %%
apli = shp_apli[(shp_apli['unidad_01'] == int(cod_prop)) & (shp_apli['semana'] == int(semana))]

# %%
prop = cat[cat['unidad_01'] == int(cod_prop)]

# %%
apli.head(3)
# Out:
#                   id  unidad_01            unidad_02  unidad_03  \
# 939   00003330000A-4        333  LA CUTA--JUSTINIANO       6550
# 940  00003330000A-11        333  LA CUTA--JUSTINIANO       6550
# 941   00003330000B-6        333  LA CUTA--JUSTINIANO       6550
#
#                      unidad_04 unidad_05    variedad          fs variedad23  \
# 939  JUSTINIANO PEREYRA ALVARO       A-4        RB-2  2020-04-10       None
# 940  JUSTINIANO PEREYRA ALVARO      A-11        RB-2  2021-05-15       None
# 941  JUSTINIANO PEREYRA ALVARO       B-6  RENOVACION        None       RB-2
#
#     textura  ... soca  cultivo zona        fs23 ins  finan2023  area  Tecnico  \
# 939       F  ...    2    canha   69        None  69       None  6.25     None
# 940      FY  ...    1    canha   69        None  69       None  4.60     None
# 941      FA  ...  122  siembra   69  2023-05-30  69     PROPIO  5.16     None
#
#     semana                                           geometry
# 939     45  POLYGON Z ((489100.657 8082544.414 0.000, 4890...
# 940     45  POLYGON Z ((489517.492 8082644.587 0.000, 4896...
# 941     45  POLYGON Z ((490481.443 8083498.742 0.000, 4905...
#
# [3 rows x 21 columns]

# %%
apli['area'].sum()
# Out:
# 30.709433708639995

# %%
registro.columns
# Out:
# Index(['Nº DE LABOR', 'FECHA', 'SEMANA', 'INSTITUCIÓN', 'COD CAÑERO',
#        'NOMBRE CAÑERO', 'COD PROPIEDAD', 'NOMBRE DE PROPIEDAD',
#        'LABOR_REALIZADA', 'HORA DE INICIO', 'HORA FINAL', 'TEMPERATURA °C',
#        'VIENTO', 'HUMEDAD', 'LOTE', 'HECTÁREAS', 'PRODUCTO', 'DOSIS',
#        'OPERACIÓN DETENIDA POR:', 'COD DRONE', 'PILOTO', 'NRO. LIBERACION',
#        'OBSERVACIONES', 'CONFORMIDAD DEL CAÑERO/SUPERVISOR', 'ORIGEN', 'IDD',
#        'REPORTE'],
#       dtype='object')

# %%
registro['HECTÁREAS'].sum()
# Out:
# 29.0

# %%
total_area = apli['area'].sum()
total_area
# Out:
# 30.709433708639995

# %%
total_ha = registro['HECTÁREAS'].sum()
total_ha
# Out:
# 29.0

# %%
diff = total_ha - total_area
diff
# Out:
# -1.7094337086399953

# %%
if diff > 0:
    cantidad = len(apli)
    incre = diff / cantidad
    apli['area'] = apli['area'] + incre
else:
    diff = diff * (-1)
    cantidad = len(apli)
    incre = diff / cantidad
    apli['area'] = apli['area'] - incre
# Out:
# C:\Users\Usuario\anaconda3\envs\utea_reportes\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
apli['area'].sum()
# Out:
# 29.000000000000007

# %%
apli['area']
# Out:
# 939     5.965094
# 940     4.315094
# 941     4.875094
# 1048    7.384888
# 1049    3.437190
# 1050    3.022639
# Name: area, dtype: float64

# %%
lotes = []
for i, r in apli.iterrows():
    lote = {
        'nombre' : r['unidad_05'],
        'area' : round(r['area'], 2)
    }
    collec = collections.namedtuple("lote", lote.keys())(*lote.values())
    lotes.append(collec)
lotes
# Out:
# [lote(nombre='A-4', area=5.97),
#  lote(nombre='A-11', area=4.32),
#  lote(nombre='B-6', area=4.88),
#  lote(nombre='A-3', area=7.38),
#  lote(nombre='A-13', area=3.44),
#  lote(nombre='B-8', area=3.02)]

# %%
filename_img = str(data_rep['cod_ca']) + '_' + str(data_rep['cod_prop']) + '_' + data_rep['fecha']
filename_img
# Out:
# '6550_333_2023-11-09'

# %%
apli = apli.to_crs(epsg=3857)
prop = prop.to_crs(epsg=3857)
# Asegúrate de que 'gdf' es tu GeoDataFrame que ya tiene una columna 'geometry' con polígonos
# Crea una figura y un eje con Matplotlib
fig, ax = plt.subplots(figsize=(12, 8))

prop.plot(ax=ax, edgecolor='blue', facecolor='none', linewidth=1)
# Grafica los polígonos utilizando la función plot de Geopandas
# 'edgecolor' es el color del borde, 'facecolor' es el color de relleno
apli.plot(ax=ax, edgecolor='yellow', facecolor='none', linewidth=2)

for idx, row in apli.iterrows():
    # Representa el punto central del polígono
    centroid = row.geometry.centroid
    # Anota el 'id' en el centro
    ax.annotate(
        text=row['unidad_05'] + ' \n' + str(round(row['area'], 2)) + 'ha', 
        xy=(centroid.x, centroid.y), 
        ha='center', 
        va='center', 
        weight=1000,
        fontsize=6,
        bbox=dict(facecolor=(1,1,1,0.3), edgecolor='none', pad=0))


# Agregar la imagen de satélite como mapa base con Contextily
ctx.add_basemap(ax, source=ctx.providers.Esri.WorldImagery)

# Ajustar los límites del eje al área de los polígonos
#ax.set_xlim(apli.total_bounds[[0, 2]])
#ax.set_ylim(apli.total_bounds[[1, 3]])

minx, miny, maxx, maxy = prop.total_bounds
ax.set_xlim(minx - 500, maxx + 500)
ax.set_ylim(miny - 400, maxy + 400)

handle1 = mpatches.Patch(color='blue', label='Lotes de propiedad')
handle2 = mpatches.Patch(color='yellow', label='Lotes con liberacion')

# Añade la leyenda con los handles creados
ax.legend(handles=[handle1, handle2])

# Omitir los ejes para una visualización más limpia
ax.axis('off')

# Muestra el gráfico
ruta_plano = ruta + '/planos/' + filename_img + '.jpeg'
fig.savefig(ruta_plano, dpi = 300, bbox_inches='tight')
plt.show()
plt.clf()

# %%
ruta
# Out:
# 'G:\\OneDrive - Ingenio Azucarero Guabira S.A\\_DATOS_PYTHON'

# %%
lista_imgs = []

# %%
lista_imgs.append(ruta_plano)

# %%
ruta_plano
# Out:
# 'G:\\OneDrive - Ingenio Azucarero Guabira S.A\\_DATOS_PYTHON/planos/6550_333_2023-11-09.jpeg'

# %%
data_rep
# Out:
# {'nro_reg': '000B-31',
#  'fecha': '2023-11-09',
#  'nom_ca': 'JUSTINIANO PEREYRA ALVARO',
#  'cod_ca': 6550,
#  'nom_prop': 'LA CUTA--JUSTINIANO',
#  'cod_prop': 333,
#  'inst': 69,
#  'total': 29.0,
#  'temp': 30,
#  'viento': 0,
#  'humedad': 69,
#  'cod_dron': 'PHANTON 4',
#  'piloto': 'JOSUE CANEDO'}

# %%
# Datos que quieres que contenga el QR
texto = '''
--UTEA--
--LIBERACION DE TRICHOGRAMMA--

Numero de Liberacion: {nro_reg}
Fecha de Liberacion: {fecha}
Nombre de Canero: {canero}
Codigo Canero: {cod_ca}
Propiedad: {prop}
Total Area Liberada: {area} ha'''\
.format(
    nro_reg=data_rep['nro_reg'], 
    fecha=data_rep['fecha'], 
    canero=data_rep['nom_ca'],
    cod_ca=data_rep['cod_ca'],
    prop=data_rep['nom_prop'],
    area=data_rep['total'])
# Generar el código QR
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_L,
    box_size=10,
    border=4,
)
qr.add_data(texto)
qr.make(fit=True)

img = qr.make_image(fill_color="black", back_color="white")

filename_qr = 'qr_' + str(data_rep['cod_ca']) + '_' + str(data_rep['cod_prop']) + '_' + data_rep['fecha']
ruta_qr = ruta + '/planos/' + filename_qr + '.png'
# Guardar el código QR en un archivo
img.save(ruta_qr)

# %%
ruta_qr
# Out:
# 'G:\\OneDrive - Ingenio Azucarero Guabira S.A\\_DATOS_PYTHON/planos/qr_6550_333_2023-11-09.png'

# %%
ruta_plano
# Out:
# 'G:\\OneDrive - Ingenio Azucarero Guabira S.A\\_DATOS_PYTHON/planos/6550_333_2023-11-09.jpeg'

# %%
doc = DocxTemplate(ruta + "/templates/tpl_rpt_liberacion_tricho.docx")
in_line_plano = docxtpl.InlineImage(doc, image_descriptor=ruta_plano, width=Mm(170))
in_line_qr = docxtpl.InlineImage(doc, image_descriptor=ruta_qr, width=Mm(30))
context = {'data':data_rep2, 'lotes':lotes, 'plano':in_line_plano, 'qr':in_line_qr}
doc.render(context)
filename = str(data_rep['cod_ca']) + '_' + data_rep['nom_ca'] + '_' + data_rep['fecha']
doc.save(ruta + '/informes/' + filename + '.docx')
