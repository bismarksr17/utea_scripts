# %%
import geopandas as gpd
import matplotlib.pyplot as plt

import tkinter as tk
from tkinter import filedialog as fd

import os
from tkinter.filedialog import askdirectory

# %%
# open file dialog
root = tk.Tk()
root.attributes('-topmost', True)
root.iconify()
file_name = fd.askopenfilename(parent=root, filetypes=[(".shp", ".shp")])
root.destroy()

# %%
file_name
# Out:
# 'D:/OneDrive - Ingenio Azucarero Guabira S.A/UTEA_2023/CATASTRO/CATASTRO_2023-02-03.shp'

# %%
# leer el .shp seleccionado
data = gpd.read_file(file_name)
data.plot()
plt.show()

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data.dtypes
# Out:
# id             object
# unidad_01     float64
# unidad_02      object
# unidad_03     float64
# unidad_04      object
# unidad_05      object
# variedad       object
# fs             object
# textura        object
# financia       object
# soca            int64
# cultivo        object
# zona            int64
# area          float64
# geometry     geometry
# dtype: object

# %%
data.head(3)
# Out:
#                 id  unidad_01       unidad_02  unidad_03  \
# 0  00005600000L1.3      560.0  LA_TUJA_IAG_SA    15284.0
# 1  00005600000L1.5      560.0  LA_TUJA_IAG_SA    15284.0
# 2  00005600000L2.2      560.0  LA_TUJA_IAG_SA    15284.0
#
#                       unidad_04 unidad_05      variedad          fs textura  \
# 0  ROJAS_CORDOVA_ROGELIO_FELIPE      L1.3     UCG_90-20  2018-05-30      FY
# 1  ROJAS_CORDOVA_ROGELIO_FELIPE      L1.5     UCG_90-20  2011-05-20      FY
# 2  ROJAS_CORDOVA_ROGELIO_FELIPE      L2.2  CITTCA_85-22  2018-05-20      FY
#
#   financia  soca cultivo  zona      area  \
# 0      IAG     4   canha    79  0.771315
# 1     None    11   canha    79  3.831973
# 2      IAG     4   canha    79  2.245713
#
#                                             geometry
# 0  POLYGON Z ((491741.706 8084531.788 0.000, 4916...
# 1  POLYGON Z ((491971.566 8084838.542 0.000, 4920...
# 2  POLYGON Z ((492266.427 8084941.630 0.000, 4923...

# %%
data = data.dropna(subset=['geometry'])

# %%
dissolved = data.dissolve(by='unidad_01')
# Out:
# TopologyException: Input geom 0 is invalid: Self-intersection at or near point 500494.81370605587 8090880.3779164087 0 at 500494.81370605587 8090880.3779164087 0
# TopologyException: Input geom 0 is invalid: Self-intersection at or near point 500494.81370605587 8090880.3779164087 0 at 500494.81370605587 8090880.3779164087 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\estimativa_01\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     258             try:
# --> 259                 return self._python_agg_general(func, *args, **kwargs)
#     260             except (ValueError, KeyError):
#
# ~\.conda\envs\estimativa_01\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#    1172                 # if this function is invalid for this dtype, we will ignore it.
# -> 1173                 result, counts = self.grouper.agg_series(obj, f)
#    1174             except TypeError:
#
# ~\.conda\envs\estimativa_01\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     698             # TODO: can we get a performant workaround for EAs backed by ndarray?
# --> 699             return self._aggregate_series_pure_python(obj, func)
#     700
#
# ~\.conda\envs\estimativa_01\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#     748             #  libreduction._BaseGrouper._apply_to_group
# --> 749             res = func(group)
#     750             res = libreduction.extract_result(res)
#
# ~\.conda\envs\estimativa_01\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#    1159         func = self._is_builtin_func(func)
# -> 1160         f = lambda x: func(x, *args, **kwargs)
#    1161
#
# ~\.conda\envs\estimativa_01\lib\site-packages\geopandas\geodataframe.py in merge_geometries(block)
#    1496         def merge_geometries(block):
# -> 1497             merged_geom = block.unary_union
#    1498             return merged_geom
#
# ~\.conda\envs\estimativa_01\lib\site-packages\geopandas\base.py in unary_union(self)
#     723         """
# --> 724         return self.geometry.values.unary_union()
#     725
#
# ~\.conda\envs\estimativa_01\lib\site-packages\geopandas\array.py in unary_union(self)
#     668     def unary_union(self):
# --> 669         return vectorized.unary_union(self.data)
#     670
#
# ~\.conda\envs\estimativa_01\lib\site-packages\geopandas\_vectorized.py in unary_union(data)
#     876     else:
# --> 877         return shapely.ops.unary_union(data)
#     878
#
# ~\.conda\envs\estimativa_01\lib\site-packages\shapely\ops.py in unary_union(self, geoms)
#     153         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
# --> 154         return geom_factory(lgeos.methods['unary_union'](collection))
#     155
#
# ~\.conda\envs\estimativa_01\lib\site-packages\shapely\geometry\base.py in geom_factory(g, parent)
#      77     if not g:
# ---> 78         raise ValueError("No Shapely geometry can be created from null value")
#      79     ob = BaseGeometry()
#
# ValueError: No Shapely geometry can be created from null value
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12900\1156451944.py in <module>
# ----> 1 dissolved = data.dissolve(by='unidad_01')
#
# ~\.conda\envs\estimativa_01\lib\site-packages\geopandas\geodataframe.py in dissolve(self, by, aggfunc, as_index, level, sort, observed, dropna)
#    1499
#    1500         g = self.groupby(group_keys=False, **groupby_kwargs)[self.geometry.name].agg(
# -> 1501             merge_geometries
#    1502         )
#    1503
#
# ~\.conda\envs\estimativa_01\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     261                 # TODO: KeyError is raised in _python_agg_general,
#     262                 #  see test_groupby.test_basic
# --> 263                 result = self._aggregate_named(func, *args, **kwargs)
#     264
#     265             index = Index(sorted(result), name=self.grouper.names[0])
#
# ~\.conda\envs\estimativa_01\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     478             group.name = name  # NB: libreduction does not pin name
#     479
# --> 480             output = func(group, *args, **kwargs)
#     481             output = libreduction.extract_result(output)
#     482             if not initialized:
#
# ~\.conda\envs\estimativa_01\lib\site-packages\geopandas\geodataframe.py in merge_geometries(block)
#    1495         # Process spatial component
#    1496         def merge_geometries(block):
# -> 1497             merged_geom = block.unary_union
#    1498             return merged_geom
#    1499
#
# ~\.conda\envs\estimativa_01\lib\site-packages\geopandas\base.py in unary_union(self)
#     722         POLYGON ((0 0, 0 1, 0 2, 2 2, 2 0, 1 0, 0 0))
#     723         """
# --> 724         return self.geometry.values.unary_union()
#     725
#     726     #
#
# ~\.conda\envs\estimativa_01\lib\site-packages\geopandas\array.py in unary_union(self)
#     667
#     668     def unary_union(self):
# --> 669         return vectorized.unary_union(self.data)
#     670
#     671     #
#
# ~\.conda\envs\estimativa_01\lib\site-packages\geopandas\_vectorized.py in unary_union(data)
#     875         return _pygeos_to_shapely(pygeos.union_all(data))
#     876     else:
# --> 877         return shapely.ops.unary_union(data)
#     878
#     879
#
# ~\.conda\envs\estimativa_01\lib\site-packages\shapely\ops.py in unary_union(self, geoms)
#     152             subs[i] = g._geom
#     153         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
# --> 154         return geom_factory(lgeos.methods['unary_union'](collection))
#     155
#     156 operator = CollectionOperator()
#
# ~\.conda\envs\estimativa_01\lib\site-packages\shapely\geometry\base.py in geom_factory(g, parent)
#      76     # Abstract geometry factory for use with topological methods below
#      77     if not g:
# ---> 78         raise ValueError("No Shapely geometry can be created from null value")
#      79     ob = BaseGeometry()
#      80     geom_type = geometry_type_name(g)
#
# ValueError: No Shapely geometry can be created from null value
